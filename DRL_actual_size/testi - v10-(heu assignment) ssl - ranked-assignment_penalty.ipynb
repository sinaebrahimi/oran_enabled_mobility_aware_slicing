# %%
# %run "main_constraint-based.py"
# Out:
# 1 6000
# /share/home2/ebrahimis/project1_3_8/venv/lib/python3.8/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/DRL_actual_size/radio_calc.py:555: RuntimeWarning: divide by zero encountered in log10
#   self.signal_strength_dB[u] = 10 * np.log10(self.signal_strength)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/DRL_actual_size/radio_calc.py:559: RuntimeWarning: divide by zero encountered in log10
#   self.SINR_dB[u] = 10 * np.log10(self.SINR)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/DRL_actual_size/radio_calc.py:553: RuntimeWarning: divide by zero encountered in log10
#   self.interference_dB[u] = 10 * np.log10(I_inter)
# reward:  0.3487274981310671
# -------------
# Reward (Until timestep 0/6000 of run 0/1):
# -------------
# reward:  -0.12228250584298017
# -------------
# Reward (Until timestep 300/6000 of run 0/1):
# -------------
# reward:  -0.23725395021480666
# -------------
# Reward (Until timestep 600/6000 of run 0/1):
# -------------
# reward:  -0.10758791346667759
# -------------
# Reward (Until timestep 900/6000 of run 0/1):
# -------------
# reward:  -0.04737155340372029
# -------------
# Reward (Until timestep 1200/6000 of run 0/1):
# -------------
# reward:  0.5278781952085279
# -------------
# Reward (Until timestep 1500/6000 of run 0/1):
# -------------
# reward:  0.09403409085760628
# -------------
# Reward (Until timestep 1800/6000 of run 0/1):
# -------------
# reward:  -0.17362680070370176
# -------------
# Reward (Until timestep 2100/6000 of run 0/1):
# -------------
# reward:  0.34347068959596333
# -------------
# Reward (Until timestep 2400/6000 of run 0/1):
# -------------
# reward:  -0.13662732615137183
# -------------
# Reward (Until timestep 2700/6000 of run 0/1):
# -------------
# reward:  0.36153439322829856
# -------------
# Reward (Until timestep 3000/6000 of run 0/1):
# -------------
# reward:  -0.03511191133052277
# -------------
# Reward (Until timestep 3300/6000 of run 0/1):
# -------------
# reward:  0.5733160856014701
# -------------
# Reward (Until timestep 3600/6000 of run 0/1):
# -------------
# reward:  -0.32940317948902775
# -------------
# Reward (Until timestep 3900/6000 of run 0/1):
# -------------
# reward:  0.03311274286855126
# -------------
# Reward (Until timestep 4200/6000 of run 0/1):
# -------------
# reward:  -0.04030732221974692
# -------------
# Reward (Until timestep 4500/6000 of run 0/1):
# -------------
# reward:  -0.36774618959329963
# -------------
# Reward (Until timestep 4800/6000 of run 0/1):
# -------------
# reward:  0.33461475668873325
# -------------
# Reward (Until timestep 5100/6000 of run 0/1):
# -------------
# reward:  -0.003302136018361379
# -------------
# Reward (Until timestep 5400/6000 of run 0/1):
# -------------
# reward:  -0.0791434544682712
# -------------
# Reward (Until timestep 5700/6000 of run 0/1):
# -------------
# Total Handovers  over all timesteps: Episode 0= 22037 HOs, reward= 0.17740990614687224
# -------------
# Runtime Duration:
# -------------
# -------------
# Avg PRBs used per user for SAC algorithm:
# -------------
# -------------
# User assignment penalty:
# -------------
# -------------
# logarithmic rewards:
# -------------
# -------------
# Mean episodic rewards:
# -------------
# -------------
# Constraint Satisfaction:
# -------------
# -------------
# SSL Metrics:
# -------------
# -------------
# Comparison of Average E2E Delay (SAC):
# -------------
# -------------
# Average Data Rate (SAC):
# -------------
# -------------
# Average of total allocated power to each user (SAC):
# -------------
# -------------
# Sum of handovers :
# -------------
# -------------
# No. of satisfied delay and rate constraints (Max= 2*U):
# -------------
# Total time for 6000 timesteps (10 users) in 1 Episdoes (aka iterations or epochs): 13.0 minutes 21.57517123222351 seconds

# %%
plot_graph("Mean episodic rewards",
           [moving_average(np.average(mat_reward[:,2000:3998], axis=0), window_size)],
           ['SAC'],
           ['blue'],
           ['solid'],
           "Episode",
           "Mean episodic rewards")

# %%
# config.yaml lstm
# config.yaml 
USER_NO: 10 #10 #20 # 4
BW: 180000  # %  180 kHz  (to be updated after consulting with Faouzi)
PRB_NO: 150 #  (to be updated after consulting with Faouzi)
SIGMA_NOISE: 10**(-17.4) #3.981e-18 # # = -174 dBm <tnsm23nouruzi> #
ETA_AREA: 3 # for rural areas according to TS 38.215 (Used in the Rayleigh/Distance formula for calculating data rate (Shannon)); equal to 3 for rural; 4 for urban areas # check also 38.913 for mobility scenarios and classes
X_LIM: 1000
Y_LIM: 1000
#CU_NO: 1 # only 1 CU is envisioned. It is co-located with the Near-RT RIC
DU_NO: 2 # all connected to the CU
RU_PER_DU_NO: 2 # Each DU has 4 RUs; Total number of RUs = 4*2 = 8
#BS_NO: 20 # should be equal to RU_PER_DU_NO*DU_NO # static for now; Location.bs_location() --- now it is bound to 4 BSs. Can be changed later
FH_BW_CAPACITY: 5000 # 100 Mbps in twc23kavehmadani# Mbps (5 Gbps) (link between RU and its DU) #
E2_BW_CAPACITY: 100000 # 5 Gbps in twc23kavehmadani #Mbps (100 Gbps) (link between DU and Near-RT RIC (equal to F1, which is between DU and CU))
#VM_NO: 9 # 6
#VNF_NO: 5 # 5
#NODE_NO: 12
SLICE_NO: 3 #5 # number of slice types ; will be indexed from 0 to (SLICE_NO - 1)
MAX_POWER: 40 # in watts ; equals to 46 dBm <tvt23choi> # 12 # (to be updated after consulting with Faouzi) # 46 dBm in tvt23choi = 40 watts (Much higher than normal papers)
OMEGA_1: 0.3 # to use in SSL weighting (for data rate term)
VELOCITY: 10 #0 #-1 means random #35 # m/s [5,20,35,50] #             = self.V ##################################################
CONST_D_MAX: -1  #-1 # -1 # 20 #-1 # ms
CONST_R_MIN: -1  #-1 # -1 # 5 #-1 # Mbps  
#ISOLATION_ORDER: -1
PACKET_SIZE: -1 #-1 # -1 # 0.012 # based on 1500 bytes for eMBB # in mbits # -1 # twc23kavehmadani: 1 KB for URLLC and 125 KB for eMBB
#PACKET_NO: 830  # 500 # -1 # packet generation rate per second # 0.012*500 = 6 Mbps # 0.012*830 = 9.96 Mbps
RAYLEIGH_SCALE: 1 # sigma in Rayleigh formula
#Episodes (T) and Number of monte-carlo runs:#
E: 1 #1000# episodes/epochs for learning (the loop before T loop (replaces MC loop))
T: 4000 #100# 14000 # 1000  # Number of timeslots
#MC: 3  # Number of Monte-carlo runs
#Hyperparameters for the DRL algorithm
ALPHA_ACT: 0.000002 #01 # 0.00001 # 0.00001 #0.000001 # actor's learning rate
BETA_ACT: 0.00001 # 5 # 0.00005 # 0.00005 # 0.00005 # 0.000005 # Critic's learning rate
VAR: 1
DECAY_VAR: 0.999 #95 #95 # .995 # can determine the ratio of exploration to exploitation
PSI: 0.5 # for putting two last actions in states
XI: 3 # shaping parameter for SSL^B_u and SSL^D_u
IOTA: 0.1 # regularization parameter that controls the penalty for low satisfaction levels
