# %%
# %run "main_constraint-based.py"
# Out:
# /share/home2/ebrahimis/project1_3_8/venv/lib/python3.8/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:397: RuntimeWarning: divide by zero encountered in log10
#   self.signal_strength_dB[u] = 10 * np.log10(self.signal_strength)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:401: RuntimeWarning: divide by zero encountered in log10
#   self.SINR_dB[u] = 10 * np.log10(self.SINR)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:395: RuntimeWarning: divide by zero encountered in log10
#   self.interference_dB[u] = 10 * np.log10(I_inter)
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 20 of episode 0
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Total Handovers  over all timesteps: Episode 0= 0 HOs
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 6 of episode 1
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 11 of episode 2
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 37 of episode 3
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 33 of episode 4
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 15 of episode 5
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 12 of episode 6
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 26 of episode 6
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 43 of episode 6
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 3 of episode 7
# meow
# meow
# Unsatisfied delay constraint in timestep 6 of episode 7
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 37 of episode 7
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 13 of episode 8
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 37 of episode 8
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 33 of episode 10
# meow
# Unsatisfied delay constraint in timestep 34 of episode 10
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 45 of episode 10
# meow
# Unsatisfied delay constraint in timestep 46 of episode 10
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 4 of episode 11
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 32 of episode 13
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 33 of episode 14
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 0 of episode 15
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 46 of episode 15
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 24 of episode 17
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 3 of episode 19
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 47 of episode 20
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 11 of episode 21
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 27 of episode 21
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 45 of episode 22
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 30 of episode 23
# meow
# meow
# Unsatisfied delay constraint in timestep 34 of episode 23
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 18 of episode 25
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 26 of episode 25
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 48 of episode 25
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 18 of episode 26
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 6 of episode 28
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 13 of episode 32
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 28 of episode 32
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 6 of episode 33
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 0 of episode 35
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 5 of episode 35
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 8 of episode 35
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 20 of episode 35
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 24 of episode 35
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 28 of episode 35
# meow
# meow
# Unsatisfied delay constraint in timestep 30 of episode 35
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# Unsatisfied delay constraint in timestep 9 of episode 36
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# meow
# -------------
# Runtime Duration:
# -------------
# -------------
# Avg PRBs used per user for SAC algorithm:
# -------------
# -------------
# Jain's fairness index for PRB allocation:
# -------------
# -------------
# Mean episodic rewards:
# -------------
# -------------
# Constraint Satisfaction:
# -------------
# -------------
# SSL Metrics:
# -------------
# -------------
# Comparison of Average E2E Delay (SAC):
# -------------
# -------------
# Average Data Rate (SAC):
# -------------
# -------------
# Average of total allocated power to each user (SAC):
# -------------
# Total time for 50 timesteps (5 users) in 40 Episdoes (aka iterations or epochs): 51.66770935058594 seconds

# %%
self.gamma = 0.99

# config.yaml
USER_NO: 8 #10 #20 # 4
BW: 180000  # %  180 kHz  (to be updated after consulting with Faouzi)
PRB_NO: 200 #  (to be updated after consulting with Faouzi)
SIGMA_NOISE: 10**(-17.4) #3.981e-18 # # = -174 dBm <tnsm23nouruzi> #
ETA_AREA: 3 # for rural areas according to TS 38.215 (Used in the Rayleigh/Distance formula for calculating data rate (Shannon)); equal to 3 for rural; 4 for urban areas # check also 38.913 for mobility scenarios and classes
X_LIM: 1000
Y_LIM: 1000
#CU_NO: 1 # only 1 CU is envisioned. It is co-located with the Near-RT RIC
DU_NO: 1 # all connected to the CU
RU_PER_DU_NO: 4 # Each DU has 4 RUs; Total number of RUs = 4*2 = 8
#BS_NO: 20 # should be equal to RU_PER_DU_NO*DU_NO # static for now; Location.bs_location() --- now it is bound to 4 BSs. Can be changed later
FH_BW_CAPACITY: 5000 # 100 Mbps in twc23kavehmadani# Mbps (5 Gbps) (link between RU and its DU) #
E2_BW_CAPACITY: 100000 # 5 Gbps in twc23kavehmadani #Mbps (100 Gbps) (link between DU and Near-RT RIC (equal to F1, which is between DU and CU))
#VM_NO: 9 # 6
#VNF_NO: 5 # 5
#NODE_NO: 12
SLICE_NO: 1 #5 # number of slice types ; will be indexed from 0 to (SLICE_NO - 1)
MAX_POWER: 40 # in watts ; equals to 46 dBm <tvt23choi> # 12 # (to be updated after consulting with Faouzi) # 46 dBm in tvt23choi = 40 watts (Much higher than normal papers)
OMEGA_1: 0.5 # to use in SSL weighting (for data rate term)
VELOCITY: 10 #0 #-1 means random #35 # m/s [5,20,35,50] #             = self.V ##################################################
CONST_D_MAX: 20 #-1 # ms
CONST_R_MIN: 10 #-1 # Mbps  
#ISOLATION_ORDER: -1
PACKET_SIZE: 0.012 # based on 1500 bytes for eMBB # in mbits # -1 # twc23kavehmadani: 1 KB for URLLC and 125 KB for eMBB
#PACKET_NO: 830  # 500 # -1 # packet generation rate per second # 0.012*500 = 6 Mbps # 0.012*830 = 9.96 Mbps
RAYLEIGH_SCALE: 1 # sigma in Rayleigh formula
#Episodes (T) and Number of monte-carlo runs:#
E: 4000 #1000# episodes/epochs for learning (the loop before T loop (replaces MC loop))
T: 50 #100# 14000 # 1000  # Number of timeslots
#MC: 3  # Number of Monte-carlo runs
#Hyperparameters for the DRL algorithm
ALPHA_ACT: 0.00001 # 0.00001 # 0.00001 #0.000001 # actor's learning rate
BETA_ACT: 0.00005 # 0.00005 # 0.00005 # 0.000005 # Critic's learning rate
VAR: 1
DECAY_VAR: 0.9994 #95 #95 # .995 # can determine the ratio of exploration to exploitation
