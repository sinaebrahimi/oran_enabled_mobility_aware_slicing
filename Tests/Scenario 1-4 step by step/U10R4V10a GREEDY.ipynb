# %%
# %run "main_constraint-based.py"
# Out:
# 0
# Handover in timestep 2 for user 2: from RU 0.0 to RU 2.0
# /share/home2/ebrahimis/project1_3_8/venv/lib/python3.8/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:395: RuntimeWarning: divide by zero encountered in log10
#   self.interference_dB[u] = 10 * np.log10(I_inter)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:397: RuntimeWarning: divide by zero encountered in log10
#   self.signal_strength_dB[u] = 10 * np.log10(self.signal_strength)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:401: RuntimeWarning: divide by zero encountered in log10
#   self.SINR_dB[u] = 10 * np.log10(self.SINR)
# Handover in timestep 17 for user 0: from RU 0.0 to RU 2.0
# Handover in timestep 64 for user 2: from RU 2.0 to RU 3.0
# Handover in timestep 85 for user 0: from RU 2.0 to RU 0.0
# Handover in timestep 249 for user 0: from RU 0.0 to RU 1.0
# Handover in timestep 302 for user 2: from RU 3.0 to RU 2.0
# Handover in timestep 363 for user 1: from RU 2.0 to RU 0.0
# Handover in timestep 392 for user 0: from RU 1.0 to RU 3.0
# Handover in timestep 573 for user 0: from RU 3.0 to RU 2.0
# Handover in timestep 759 for user 1: from RU 0.0 to RU 1.0
# Handover in timestep 760 for user 1: from RU 1.0 to RU 0.0
# Handover in timestep 780 for user 2: from RU 2.0 to RU 0.0
# Handover in timestep 872 for user 0: from RU 2.0 to RU 0.0
# Total Handovers  over all timesteps: MC 0= 13 HOs
# 0
# Handover in timestep 50 for user 1: from RU 2.0 to RU 3.0
# Handover in timestep 64 for user 0: from RU 2.0 to RU 3.0
# Handover in timestep 83 for user 0: from RU 3.0 to RU 2.0
# Handover in timestep 114 for user 1: from RU 3.0 to RU 1.0
# Handover in timestep 122 for user 2: from RU 0.0 to RU 2.0
# Handover in timestep 173 for user 0: from RU 2.0 to RU 0.0
# Handover in timestep 195 for user 0: from RU 0.0 to RU 2.0
# Handover in timestep 215 for user 0: from RU 2.0 to RU 0.0
# Handover in timestep 237 for user 1: from RU 1.0 to RU 0.0
# Handover in timestep 242 for user 1: from RU 0.0 to RU 1.0
# Handover in timestep 248 for user 0: from RU 0.0 to RU 2.0
# Handover in timestep 266 for user 0: from RU 2.0 to RU 0.0
# Handover in timestep 453 for user 1: from RU 1.0 to RU 3.0
# Handover in timestep 495 for user 0: from RU 0.0 to RU 2.0
# Handover in timestep 638 for user 1: from RU 3.0 to RU 2.0
# Handover in timestep 641 for user 1: from RU 2.0 to RU 3.0
# Handover in timestep 647 for user 1: from RU 3.0 to RU 2.0
# Handover in timestep 675 for user 0: from RU 2.0 to RU 0.0
# Handover in timestep 695 for user 2: from RU 2.0 to RU 0.0
# Handover in timestep 696 for user 2: from RU 0.0 to RU 2.0
# Handover in timestep 730 for user 2: from RU 2.0 to RU 0.0
# Handover in timestep 790 for user 2: from RU 0.0 to RU 2.0
# Handover in timestep 823 for user 1: from RU 2.0 to RU 0.0
# Handover in timestep 831 for user 0: from RU 0.0 to RU 1.0
# Handover in timestep 843 for user 2: from RU 2.0 to RU 3.0
# Handover in timestep 878 for user 1: from RU 0.0 to RU 1.0
# Handover in timestep 881 for user 1: from RU 1.0 to RU 0.0
# Handover in timestep 921 for user 0: from RU 1.0 to RU 3.0
# Handover in timestep 951 for user 1: from RU 0.0 to RU 2.0
# Handover in timestep 968 for user 1: from RU 2.0 to RU 0.0
# Total Handovers  over all timesteps: MC 1= 30 HOs
# -------------
# Runtime Duration:
# -------------
# -------------
# Avg PRBs used per user for SAC algorithm:
# -------------
# -------------
# Jain's fairness index for PRB allocation:
# -------------
# -------------
# Mean episodic rewards:
# -------------
# -------------
# Constraint Satisfaction:
# -------------
# -------------
# SSL Metrics:
# -------------
# -------------
# Comparison of Average E2E Delay (SAC):
# -------------
# -------------
# Average Data Rate (SAC):
# -------------
# -------------
# Average of total allocated power to each user (SAC):
# -------------
# Total time for 1000 timeslots/episodes (3 users) in 2 Monte-Carlo iterations: 1.0 minute 47.79879808425903 seconds

# %%
mean_rate_sac_0 = np.mean(shannon[:,0,:], axis=0)
mean_rate_sac_1 = np.mean(shannon[:,1,:], axis=0)
mean_rate_sac_2 = np.mean(shannon[:,2,:], axis=0)
mean_rate_sac_3 = np.mean(shannon[:,3,:], axis=0)
mean_rate_sac_4 = np.mean(shannon[:,4,:], axis=0)
mean_rate_sac_5 = np.mean(shannon[:,5,:], axis=0)
mean_rate_sac_6 = np.mean(shannon[:,6,:], axis=0)
mean_rate_sac_7 = np.mean(shannon[:,7,:], axis=0)
mean_rate_sac_8 = np.mean(shannon[:,8,:], axis=0)
mean_rate_sac_9 = np.mean(shannon[:,9,:], axis=0)
plot_graph("Average Data Rate (SAC)",
           [moving_average(mean_rate_sac_0, window_size), moving_average(mean_rate_sac_1, window_size), moving_average(mean_rate_sac_2, window_size),
            moving_average(mean_rate_sac_3, window_size), moving_average(mean_rate_sac_4, window_size), moving_average(mean_rate_sac_5, window_size),
            moving_average(mean_rate_sac_6, window_size), moving_average(mean_rate_sac_7, window_size), moving_average(mean_rate_sac_8, window_size),
            moving_average(mean_rate_sac_9, window_size)],
           ['u0', 'u1', 'u2', 'u3', 'u4', 'u5', 'u6', 'u7', 'u8', 'u9'],
           ['blue', 'red', 'green', 'purple', 'orange', 'yellow', 'brown', 'pink', 'cyan', 'magenta'],
           ['solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid'],
           "Timestep",
           "Data Rate (Mbps)")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 4
#       2 mean_rate_sac_1 = np.mean(shannon[:,1,:], axis=0)
#       3 mean_rate_sac_2 = np.mean(shannon[:,2,:], axis=0)
# ----> 4 mean_rate_sac_3 = np.mean(shannon[:,3,:], axis=0)
#       5 mean_rate_sac_4 = np.mean(shannon[:,4,:], axis=0)
#       6 mean_rate_sac_5 = np.mean(shannon[:,5,:], axis=0)
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
print(mat_associator[:,:,-90])
print(np.sum(mat_rho[0,0,:,4,-90]))
