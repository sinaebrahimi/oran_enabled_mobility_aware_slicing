# %%
# %run "r-main_constraint-based.py"
# Out:
# /share/home2/ebrahimis/project1_3_8/venv/lib/python3.8/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/sac-lstm/radio_calc.py:397: RuntimeWarning: divide by zero encountered in log10
#   self.signal_strength_dB[u] = 10 * np.log10(self.signal_strength)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/sac-lstm/radio_calc.py:401: RuntimeWarning: divide by zero encountered in log10
#   self.SINR_dB[u] = 10 * np.log10(self.SINR)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/sac-lstm/radio_calc.py:395: RuntimeWarning: divide by zero encountered in log10
#   self.interference_dB[u] = 10 * np.log10(I_inter)
# reward:  34.852512171580784
# reward:  59.21323377675886
# reward:  74.23584874606193
# Total Handovers  over all timesteps: Episode 0= 52 HOs
# Total Handovers  over all timesteps: Episode 100= 48 HOs
# reward:  86.01481223735895
# reward:  86.97480060384949
# reward:  73.96599381239497
# Total Handovers  over all timesteps: Episode 200= 91 HOs
# Total Handovers  over all timesteps: Episode 300= 18 HOs
# reward:  87.86061825811028
# reward:  60.49073224931173
# reward:  86.91192709427239
# Total Handovers  over all timesteps: Episode 400= 20 HOs
# Total Handovers  over all timesteps: Episode 500= 56 HOs
# reward:  52.11168929403247
# reward:  73.91171701315702
# reward:  71.62285437583361
# Total Handovers  over all timesteps: Episode 600= 33 HOs
# Total Handovers  over all timesteps: Episode 700= 37 HOs
# reward:  60.2351431919154
# reward:  82.45761150975397
# reward:  73.926495128925
# Total Handovers  over all timesteps: Episode 800= 20 HOs
# Total Handovers  over all timesteps: Episode 900= 27 HOs
# reward:  87.20547842036011
# reward:  87.17780573728416
# reward:  71.99795414087401
# Total Handovers  over all timesteps: Episode 1000= 29 HOs
# Total Handovers  over all timesteps: Episode 1100= 26 HOs
# reward:  84.33694170690738
# reward:  86.14489019886881
# reward:  71.67305899183233
# Total Handovers  over all timesteps: Episode 1200= 34 HOs
# Total Handovers  over all timesteps: Episode 1300= 38 HOs
# reward:  87.04587114442019
# reward:  96.60594861025666
# reward:  95.63377343022718
# Total Handovers  over all timesteps: Episode 1400= 15 HOs
# Total Handovers  over all timesteps: Episode 1500= 50 HOs
# reward:  74.4865387845054
# reward:  87.64944482077586
# reward:  84.13193762878839
# Total Handovers  over all timesteps: Episode 1600= 32 HOs
# Total Handovers  over all timesteps: Episode 1700= 36 HOs
# reward:  75.90584055285218
# reward:  94.00705212483788
# reward:  85.7866978435822
# Total Handovers  over all timesteps: Episode 1800= 50 HOs
# Total Handovers  over all timesteps: Episode 1900= 84 HOs
# -------------
# Runtime Duration:
# -------------
# -------------
# Avg PRBs used per user for SAC algorithm:
# -------------
# -------------
# Jain's fairness index for PRB allocation:
# -------------
# -------------
# Mean episodic rewards:
# -------------
# -------------
# Constraint Satisfaction:
# -------------
# -------------
# SSL Metrics:
# -------------
# -------------
# Comparison of Average E2E Delay (SAC):
# -------------
# -------------
# Average Data Rate (SAC):
# -------------
# -------------
# Average of total allocated power to each user (SAC):
# -------------
# -------------
# Sum of handovers (each episode):
# -------------
# -------------
# Average No. of handovers per user:
# -------------
# Total time for 100 timesteps (8 users) in 2000 Episdoes (aka iterations or epochs): 4.0 hours 13.0 minutes 28.08470344543457 seconds

# %%
plot_graph("Mean episodic rewards",
           [moving_average(np.average(mat_reward, axis=1), 1000)],
           ['SAC'],
           ['blue'],
           ['solid'],
           "Episode",
           "Mean episodic rewards")
# Out:
# -------------
# Mean episodic rewards:
# -------------

# %%
# config.yaml lstm
# config.yaml lstm
USER_NO: 8 #10 #20 # 4
BW: 180000  # %  180 kHz  (to be updated after consulting with Faouzi)
PRB_NO: 80 #  (to be updated after consulting with Faouzi)
SIGMA_NOISE: 10**(-17.4) #3.981e-18 # # = -174 dBm <tnsm23nouruzi> #
ETA_AREA: 3 # for rural areas according to TS 38.215 (Used in the Rayleigh/Distance formula for calculating data rate (Shannon)); equal to 3 for rural; 4 for urban areas # check also 38.913 for mobility scenarios and classes
X_LIM: 1000
Y_LIM: 1000
#CU_NO: 1 # only 1 CU is envisioned. It is co-located with the Near-RT RIC
DU_NO: 2 # all connected to the CU
RU_PER_DU_NO: 2 # Each DU has 4 RUs; Total number of RUs = 4*2 = 8
#BS_NO: 20 # should be equal to RU_PER_DU_NO*DU_NO # static for now; Location.bs_location() --- now it is bound to 4 BSs. Can be changed later
FH_BW_CAPACITY: 5000 # 100 Mbps in twc23kavehmadani# Mbps (5 Gbps) (link between RU and its DU) #
E2_BW_CAPACITY: 100000 # 5 Gbps in twc23kavehmadani #Mbps (100 Gbps) (link between DU and Near-RT RIC (equal to F1, which is between DU and CU))
#VM_NO: 9 # 6
#VNF_NO: 5 # 5
#NODE_NO: 12
SLICE_NO: 1 #5 # number of slice types ; will be indexed from 0 to (SLICE_NO - 1)
MAX_POWER: 40 # in watts ; equals to 46 dBm <tvt23choi> # 12 # (to be updated after consulting with Faouzi) # 46 dBm in tvt23choi = 40 watts (Much higher than normal papers)
OMEGA_1: 0.5 # to use in SSL weighting (for data rate term)
VELOCITY: 10 #0 #-1 means random #35 # m/s [5,20,35,50] #             = self.V ##################################################
CONST_D_MAX: 20 #-1 # ms
CONST_R_MIN: 5 #-1 # Mbps  
#ISOLATION_ORDER: -1
PACKET_SIZE: 0.012 # based on 1500 bytes for eMBB # in mbits # -1 # twc23kavehmadani: 1 KB for URLLC and 125 KB for eMBB
#PACKET_NO: 830  # 500 # -1 # packet generation rate per second # 0.012*500 = 6 Mbps # 0.012*830 = 9.96 Mbps
RAYLEIGH_SCALE: 1 # sigma in Rayleigh formula
#Episodes (T) and Number of monte-carlo runs:#
E: 2000 #1000# episodes/epochs for learning (the loop before T loop (replaces MC loop))
T: 100 #100# 14000 # 1000  # Number of timeslots
#MC: 3  # Number of Monte-carlo runs
#Hyperparameters for the DRL algorithm
ALPHA_ACT: 0.00001 # 0.00001 # 0.00001 #0.000001 # actor's learning rate
BETA_ACT: 0.00005 # 0.00005 # 0.00005 # 0.000005 # Critic's learning rate
VAR: 1
DECAY_VAR: 0.9994 #95 #95 # .995 # can determine the ratio of exploration to exploitation
