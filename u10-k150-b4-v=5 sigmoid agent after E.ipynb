# %%
# %run "main_constraint-based.py"
# Out:
# 1 500
# /share/home2/ebrahimis/project1_3_8/venv/lib/python3.8/site-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:558: RuntimeWarning: divide by zero encountered in log10
#   self.signal_strength_dB[u] = 10 * np.log10(self.signal_strength)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:562: RuntimeWarning: divide by zero encountered in log10
#   self.SINR_dB[u] = 10 * np.log10(self.SINR)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:556: RuntimeWarning: divide by zero encountered in log10
#   self.interference_dB[u] = 10 * np.log10(I_inter)
# DUPLICATED! Episode: 0, Timestep: 97, Reward: 0.9815438304081537
# DUPLICATED! Episode: 0, Timestep: 98, Reward: 0.9795848944602503
# DUPLICATED! Episode: 0, Timestep: 99, Reward: 0.9800161002753134
# DUPLICATED! Episode: 0, Timestep: 100, Reward: 0.982414053747317
# in time 100
# [659.92272255 581.91912118]
# [664.7642394  580.67023583]
# [668.33070943 584.17456051]
# DUPLICATED! Episode: 0, Timestep: 101, Reward: 0.9864557799843041
# DUPLICATED! Episode: 0, Timestep: 102, Reward: 0.9846459469878825
# DUPLICATED! Episode: 0, Timestep: 103, Reward: 0.9869282461004493
# DUPLICATED! Episode: 0, Timestep: 104, Reward: 0.9876930878036166
# DUPLICATED! Episode: 0, Timestep: 105, Reward: 0.9870603153235205
# DUPLICATED! Episode: 0, Timestep: 106, Reward: 0.9873294583217552
# DUPLICATED! Episode: 0, Timestep: 107, Reward: 0.9884471170743362
# DUPLICATED! Episode: 0, Timestep: 108, Reward: 0.9889703139859582
# DUPLICATED! Episode: 0, Timestep: 109, Reward: 0.9887472106160093
# DUPLICATED! Episode: 0, Timestep: 110, Reward: 0.9892235898316453
# DUPLICATED! Episode: 0, Timestep: 111, Reward: 0.9898684707910268
# DUPLICATED! Episode: 0, Timestep: 112, Reward: 0.9903510030024315
# DUPLICATED! Episode: 0, Timestep: 113, Reward: 0.9889647134416284
# DUPLICATED! Episode: 0, Timestep: 114, Reward: 0.9877248088323596
# DUPLICATED! Episode: 0, Timestep: 115, Reward: 0.9883977546754693
# DUPLICATED! Episode: 0, Timestep: 116, Reward: 0.9878948803395525
# DUPLICATED! Episode: 0, Timestep: 117, Reward: 0.9852435911112524
# DUPLICATED! Episode: 0, Timestep: 118, Reward: 0.9832132906942849
# DUPLICATED! Episode: 0, Timestep: 119, Reward: 0.9832205959154406
# DUPLICATED! Episode: 0, Timestep: 120, Reward: 0.981001872422017
# DUPLICATED! Episode: 0, Timestep: 121, Reward: 0.9834940904520669
# DUPLICATED! Episode: 0, Timestep: 122, Reward: 0.9827002929250304
# DUPLICATED! Episode: 0, Timestep: 123, Reward: 0.9787966129824368
# DUPLICATED! Episode: 0, Timestep: 355, Reward: 0.9705026050755164
# DUPLICATED! Episode: 0, Timestep: 356, Reward: 0.9727760363450886
# DUPLICATED! Episode: 0, Timestep: 357, Reward: 0.9733956910297649
# DUPLICATED! Episode: 0, Timestep: 358, Reward: 0.9747816860096556
# DUPLICATED! Episode: 0, Timestep: 359, Reward: 0.9742594043360482
# DUPLICATED! Episode: 0, Timestep: 360, Reward: 0.9754714194499342
# DUPLICATED! Episode: 0, Timestep: 361, Reward: 0.9780733752814982
# DUPLICATED! Episode: 0, Timestep: 362, Reward: 0.9724930880005543
# DUPLICATED! Episode: 0, Timestep: 363, Reward: 0.9710317942035454
# DUPLICATED! Episode: 0, Timestep: 364, Reward: 0.9678610336630008
# DUPLICATED! Episode: 0, Timestep: 365, Reward: 0.9696059711834456
# in time 400
# [850.3889216  463.38100117]
# [846.84527314 459.85360048]
# [851.72792668 458.77670939]
# Total Handovers  over all timesteps: Episode 0= 75 HOs, reward= 0.7381546691465511
# -------------
# Runtime Duration:
# -------------
# -------------
# Avg PRBs used per user for SAC algorithm:
# -------------
# -------------
# logarithmic rewards:
# -------------
# -------------
# Mean episodic rewards:
# -------------
# -------------
# Constraint Satisfaction:
# -------------
# -------------
# SSL Metrics:
# -------------
# -------------
# Comparison of Average E2E Delay (SAC):
# -------------
# -------------
# Average Data Rate (SAC):
# -------------
# -------------
# Average of total allocated power to each user (SAC):
# -------------
# -------------
# Sum of handovers :
# -------------
# -------------
# No. of satisfied delay and rate constraints (Max= 2*U):
# -------------
# Total time for 500 timesteps (10 users) in 1 Episdoes (aka iterations or epochs): 43.76179265975952 seconds

# %%
print(loc_user[299,:])
# Out:
# [[423.8532045  500.        ]
#  [251.0456324  500.        ]
#  [950.         500.        ]
#  [429.1694795  500.        ]
#  [888.69150211 500.        ]
#  [ 90.81567362 500.        ]
#  [712.35440702 500.        ]
#  [107.3103117  500.        ]
#  [703.90310751 500.        ]
#  [861.5136614  500.        ]]

# %%
temp_rate =mat_ssl_rate[:, :-1]
mat_ssl_rate_box = temp_rate[4,:] # np.average(temp_rate, axis=0)
data = [mat_ssl_rate_box[i*group_size:(i+1)*group_size] for i in range(num_groups)]

# Plotting
plt.figure(figsize=(12, 6))
plt.boxplot(data)
plt.xlabel('Groups of 100 Time steps')
plt.ylabel('Bitrate SSL')
plt.xticks(ticks=range(1, num_groups + 1), labels=[f'{i*group_size}-{(i+1)*group_size-1}' for i in range(num_groups)])
plt.show()

# %%
# config.yaml lstm
# config.yaml 
USER_NO: 10 #10 #20 # 4
BW: 180000  # %  180 kHz  (to be updated after consulting with Faouzi)
PRB_NO: 150 #  (to be updated after consulting with Faouzi)
SIGMA_NOISE: 10**(-17.4) #3.981e-18 # # = -174 dBm <tnsm23nouruzi> #
ETA_AREA: 3 # for rural areas according to TS 38.215 (Used in the Rayleigh/Distance formula for calculating data rate (Shannon)); equal to 3 for rural; 4 for urban areas # check also 38.913 for mobility scenarios and classes
X_LIM: 1000
Y_LIM: 1000
#CU_NO: 1 # only 1 CU is envisioned. It is co-located with the Near-RT RIC
DU_NO: 2 # all connected to the CU
RU_PER_DU_NO: 2 # Each DU has 4 RUs; Total number of RUs = 4*2 = 8
#BS_NO: 20 # should be equal to RU_PER_DU_NO*DU_NO # static for now; Location.bs_location() --- now it is bound to 4 BSs. Can be changed later
FH_BW_CAPACITY: 5000 # 100 Mbps in twc23kavehmadani# Mbps (5 Gbps) (link between RU and its DU) #
E2_BW_CAPACITY: 100000 # 5 Gbps in twc23kavehmadani #Mbps (100 Gbps) (link between DU and Near-RT RIC (equal to F1, which is between DU and CU))
#VM_NO: 9 # 6
#VNF_NO: 5 # 5
#NODE_NO: 12
SLICE_NO: 3 #5 # number of slice types ; will be indexed from 0 to (SLICE_NO - 1)
MAX_POWER: 40 # in watts ; equals to 46 dBm <tvt23choi> # 12 # (to be updated after consulting with Faouzi) # 46 dBm in tvt23choi = 40 watts (Much higher than normal papers)
OMEGA_1: 0.3 # to use in SSL weighting (for data rate term)
VELOCITY: 5 #0 #-1 means random #35 # m/s [5,20,35,50] #             = self.V ##################################################
CONST_D_MAX: 20 # -1 # 20 #-1 # ms
CONST_R_MIN: 10 # -1 # 5 #-1 # Mbps  
#ISOLATION_ORDER: -1
PACKET_SIZE: 0.012 # -1 # 0.012 # based on 1500 bytes for eMBB # in mbits # -1 # twc23kavehmadani: 1 KB for URLLC and 125 KB for eMBB
#PACKET_NO: 830  # 500 # -1 # packet generation rate per second # 0.012*500 = 6 Mbps # 0.012*830 = 9.96 Mbps
RAYLEIGH_SCALE: 1 # sigma in Rayleigh formula
#Episodes (T) and Number of monte-carlo runs:#
E: 5 #1000# episodes/epochs for learning (the loop before T loop (replaces MC loop))
T: 1000 #100# 14000 # 1000  # Number of timeslots
#MC: 3  # Number of Monte-carlo runs
#Hyperparameters for the DRL algorithm
ALPHA_ACT: 0.00001 #01 # 0.00001 # 0.00001 #0.000001 # actor's learning rate
BETA_ACT: 0.00005 # 0.00005 # 0.00005 # 0.00005 # 0.000005 # Critic's learning rate
VAR: 1
DECAY_VAR: 0.999 #95 #95 # .995 # can determine the ratio of exploration to exploitation
PSI: 0.5 # for putting two last actions in states
XI: 3 # shaping parameter for SSL^B_u and SSL^D_u
IOTA: 0.1 # regularization parameter that controls the penalty for low satisfaction levels
