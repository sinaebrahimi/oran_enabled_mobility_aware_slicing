# %%
# %run "main_constraint-based.py"
# Out:
# 100 400
# /share/home2/ebrahimis/project1_3_8/venv/lib/python3.8/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:397: RuntimeWarning: divide by zero encountered in log10
#   self.signal_strength_dB[u] = 10 * np.log10(self.signal_strength)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:401: RuntimeWarning: divide by zero encountered in log10
#   self.SINR_dB[u] = 10 * np.log10(self.SINR)
# TEST
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:395: RuntimeWarning: divide by zero encountered in log10
#   self.interference_dB[u] = 10 * np.log10(I_inter)
# Total Handovers  over all timesteps: Episode 0= 0 HOs, reward= 76.52876905527047
# TEST
# TEST
# NICE! Episode: 2, Timestep: 4, Reward: 99.21399183116782
# NICE! Episode: 2, Timestep: 9, Reward: 97.23486643307434
# NICE! Episode: 2, Timestep: 13, Reward: 97.29580684592291
# NICE! Episode: 2, Timestep: 17, Reward: 97.5326647178614
# NICE! Episode: 2, Timestep: 18, Reward: 97.50756936706662
# NICE! Episode: 2, Timestep: 22, Reward: 96.69816270380676
# NICE! Episode: 2, Timestep: 27, Reward: 97.17811992525608
# NICE! Episode: 2, Timestep: 30, Reward: 98.74864181952769
# NICE! Episode: 2, Timestep: 32, Reward: 97.73647655345971
# NICE! Episode: 2, Timestep: 38, Reward: 97.56984860705138
# NICE! Episode: 2, Timestep: 40, Reward: 97.82741841401158
# NICE! Episode: 2, Timestep: 43, Reward: 97.78902336441529
# NICE! Episode: 2, Timestep: 48, Reward: 96.45566273355762
# NICE! Episode: 2, Timestep: 51, Reward: 97.72316256922092
# NICE! Episode: 2, Timestep: 52, Reward: 98.55611266814421
# NICE! Episode: 2, Timestep: 53, Reward: 99.36599382513045
# NICE! Episode: 2, Timestep: 55, Reward: 98.20322061994742
# NICE! Episode: 2, Timestep: 56, Reward: 97.9248479281179
# NICE! Episode: 2, Timestep: 58, Reward: 96.17211192049855
# NICE! Episode: 2, Timestep: 59, Reward: 98.47303714571106
# NICE! Episode: 2, Timestep: 60, Reward: 97.37118121377625
# NICE! Episode: 2, Timestep: 61, Reward: 98.88111361499672
# NICE! Episode: 2, Timestep: 62, Reward: 97.83104331953929
# NICE! Episode: 2, Timestep: 64, Reward: 98.71005773663435
# NICE! Episode: 2, Timestep: 66, Reward: 98.93246849609271
# NICE! Episode: 2, Timestep: 68, Reward: 98.56275001857817
# NICE! Episode: 2, Timestep: 70, Reward: 98.87076022810022
# NICE! Episode: 2, Timestep: 72, Reward: 98.8233173955237
# NICE! Episode: 2, Timestep: 73, Reward: 96.29684813960237
# NICE! Episode: 2, Timestep: 74, Reward: 98.51121022149263
# NICE! Episode: 2, Timestep: 76, Reward: 98.83263444005192
# NICE! Episode: 2, Timestep: 78, Reward: 98.85856746615845
# NICE! Episode: 2, Timestep: 81, Reward: 99.30879612245195
# NICE! Episode: 2, Timestep: 83, Reward: 98.22061953129754
# NICE! Episode: 2, Timestep: 85, Reward: 97.1850944888079
# NICE! Episode: 2, Timestep: 87, Reward: 98.81019126921507
# NICE! Episode: 2, Timestep: 88, Reward: 99.04835905800553
# NICE! Episode: 2, Timestep: 89, Reward: 98.06243692809822
# NICE! Episode: 2, Timestep: 94, Reward: 97.85255975498393
# NICE! Episode: 2, Timestep: 95, Reward: 96.48508219153533
# NICE! Episode: 2, Timestep: 97, Reward: 98.43747643708326
# NICE! Episode: 2, Timestep: 98, Reward: 97.20085144364894
# NICE! Episode: 2, Timestep: 101, Reward: 97.16118175715012
# NICE! Episode: 2, Timestep: 104, Reward: 98.13449672863015
# NICE! Episode: 2, Timestep: 105, Reward: 98.45407343549026
# NICE! Episode: 2, Timestep: 107, Reward: 98.53845597354926
# NICE! Episode: 2, Timestep: 108, Reward: 98.36198448237403
# NICE! Episode: 2, Timestep: 109, Reward: 99.22940512609712
# NICE! Episode: 2, Timestep: 111, Reward: 98.91888493826373
# NICE! Episode: 2, Timestep: 112, Reward: 97.97521079883991
# NICE! Episode: 2, Timestep: 113, Reward: 99.12597166211246
# NICE! Episode: 2, Timestep: 114, Reward: 97.95512376322563
# NICE! Episode: 2, Timestep: 116, Reward: 98.51605132340973
# NICE! Episode: 2, Timestep: 118, Reward: 98.90744524023351
# NICE! Episode: 2, Timestep: 120, Reward: 98.80351258276838
# NICE! Episode: 2, Timestep: 122, Reward: 97.85036666956739
# NICE! Episode: 2, Timestep: 123, Reward: 97.82353312966089
# NICE! Episode: 2, Timestep: 124, Reward: 98.54623195308395
# NICE! Episode: 2, Timestep: 125, Reward: 97.68494741385865
# NICE! Episode: 2, Timestep: 126, Reward: 97.5510636829656
# NICE! Episode: 2, Timestep: 129, Reward: 97.51985820038108
# NICE! Episode: 2, Timestep: 131, Reward: 97.72467260401532
# NICE! Episode: 2, Timestep: 132, Reward: 97.61184250271627
# NICE! Episode: 2, Timestep: 135, Reward: 98.33010171779335
# NICE! Episode: 2, Timestep: 136, Reward: 97.35316950428549
# NICE! Episode: 2, Timestep: 139, Reward: 98.92741295751858
# NICE! Episode: 2, Timestep: 140, Reward: 97.36294084323646
# NICE! Episode: 2, Timestep: 145, Reward: 98.72200977938824
# NICE! Episode: 2, Timestep: 147, Reward: 97.64070417037154
# NICE! Episode: 2, Timestep: 148, Reward: 97.2079730421056
# NICE! Episode: 2, Timestep: 149, Reward: 97.83473548399895
# NICE! Episode: 2, Timestep: 151, Reward: 98.86896460205999
# NICE! Episode: 2, Timestep: 152, Reward: 98.25231717661804
# NICE! Episode: 2, Timestep: 153, Reward: 97.17327100563892
# NICE! Episode: 2, Timestep: 154, Reward: 97.1043291839593
# NICE! Episode: 2, Timestep: 155, Reward: 98.82478343076167
# NICE! Episode: 2, Timestep: 156, Reward: 98.58913259953306
# NICE! Episode: 2, Timestep: 157, Reward: 97.46878669640677
# NICE! Episode: 2, Timestep: 158, Reward: 97.53434873774341
# NICE! Episode: 2, Timestep: 159, Reward: 98.31936930918613
# NICE! Episode: 2, Timestep: 161, Reward: 97.8895424222166
# NICE! Episode: 2, Timestep: 162, Reward: 97.67817153215155
# NICE! Episode: 2, Timestep: 163, Reward: 98.70427943635588
# NICE! Episode: 2, Timestep: 164, Reward: 98.103212879134
# NICE! Episode: 2, Timestep: 165, Reward: 96.99211045355851
# NICE! Episode: 2, Timestep: 169, Reward: 99.14986642396181
# NICE! Episode: 2, Timestep: 171, Reward: 96.96128759709546
# NICE! Episode: 2, Timestep: 173, Reward: 97.0026505049705
# NICE! Episode: 2, Timestep: 176, Reward: 97.43818002657525
# NICE! Episode: 2, Timestep: 179, Reward: 98.67481070018728
# NICE! Episode: 2, Timestep: 182, Reward: 96.58431103820348
# NICE! Episode: 2, Timestep: 186, Reward: 98.3791300304679
# NICE! Episode: 2, Timestep: 189, Reward: 98.28469623631328
# NICE! Episode: 2, Timestep: 190, Reward: 98.7740873273801
# NICE! Episode: 2, Timestep: 191, Reward: 99.39971041420446
# NICE! Episode: 2, Timestep: 192, Reward: 96.88469605891984
# NICE! Episode: 2, Timestep: 193, Reward: 98.91631809630309
# NICE! Episode: 2, Timestep: 194, Reward: 99.35388354580854
# NICE! Episode: 2, Timestep: 195, Reward: 98.55465937130687
# NICE! Episode: 2, Timestep: 198, Reward: 99.00878785015087
# NICE! Episode: 2, Timestep: 199, Reward: 99.06975843673301
# NICE! Episode: 2, Timestep: 203, Reward: 98.98452162282896
# NICE! Episode: 2, Timestep: 204, Reward: 98.89073371740639
# NICE! Episode: 2, Timestep: 207, Reward: 99.30503198637896
# NICE! Episode: 2, Timestep: 210, Reward: 98.73134233250902
# NICE! Episode: 2, Timestep: 211, Reward: 98.59585792224316
# NICE! Episode: 2, Timestep: 214, Reward: 99.3411793008718
# NICE! Episode: 2, Timestep: 215, Reward: 98.26437190393604
# NICE! Episode: 2, Timestep: 219, Reward: 98.36856393886639
# NICE! Episode: 2, Timestep: 222, Reward: 99.23001959436814
# NICE! Episode: 2, Timestep: 223, Reward: 95.56296301770408
# NICE! Episode: 2, Timestep: 224, Reward: 99.18920092418904
# NICE! Episode: 2, Timestep: 226, Reward: 97.89044119801818
# NICE! Episode: 2, Timestep: 228, Reward: 96.23419205707582
# NICE! Episode: 2, Timestep: 229, Reward: 99.49908457191441
# NICE! Episode: 2, Timestep: 232, Reward: 99.12788793508535
# NICE! Episode: 2, Timestep: 233, Reward: 99.62983241753093
# NICE! Episode: 2, Timestep: 234, Reward: 97.8007154681422
# NICE! Episode: 2, Timestep: 235, Reward: 98.47961663923776
# NICE! Episode: 2, Timestep: 240, Reward: 98.81950622355515
# NICE! Episode: 2, Timestep: 242, Reward: 98.0310757683546
# NICE! Episode: 2, Timestep: 246, Reward: 98.37274681298649
# NICE! Episode: 2, Timestep: 251, Reward: 97.81170691030079
# NICE! Episode: 2, Timestep: 254, Reward: 98.94161361071781
# NICE! Episode: 2, Timestep: 258, Reward: 98.54173017878729
# NICE! Episode: 2, Timestep: 259, Reward: 97.327121028647
# NICE! Episode: 2, Timestep: 261, Reward: 98.2853167207924
# NICE! Episode: 2, Timestep: 265, Reward: 98.47993231240739
# NICE! Episode: 2, Timestep: 267, Reward: 97.94580883634718
# NICE! Episode: 2, Timestep: 268, Reward: 98.01286084167057
# NICE! Episode: 2, Timestep: 270, Reward: 98.10515747731775
# NICE! Episode: 2, Timestep: 272, Reward: 98.95184174644871
# NICE! Episode: 2, Timestep: 273, Reward: 97.13745601528979
# NICE! Episode: 2, Timestep: 274, Reward: 98.93067439281397
# NICE! Episode: 2, Timestep: 275, Reward: 98.95904432394886
# NICE! Episode: 2, Timestep: 276, Reward: 96.36525175445732
# NICE! Episode: 2, Timestep: 277, Reward: 95.82875474339696
# NICE! Episode: 2, Timestep: 278, Reward: 99.23841627897451
# NICE! Episode: 2, Timestep: 279, Reward: 97.68279279311488
# NICE! Episode: 2, Timestep: 280, Reward: 98.33735396299012
# NICE! Episode: 2, Timestep: 281, Reward: 98.79344479788173
# NICE! Episode: 2, Timestep: 283, Reward: 97.83643242581992
# NICE! Episode: 2, Timestep: 289, Reward: 97.76502468653327
# NICE! Episode: 2, Timestep: 291, Reward: 99.21524000322499
# NICE! Episode: 2, Timestep: 294, Reward: 97.14684116430583
# NICE! Episode: 2, Timestep: 298, Reward: 98.05556620658935
# NICE! Episode: 2, Timestep: 300, Reward: 98.0319779003386
# NICE! Episode: 2, Timestep: 302, Reward: 95.27735792462383
# NICE! Episode: 2, Timestep: 303, Reward: 99.08958138168845
# NICE! Episode: 2, Timestep: 309, Reward: 98.7928840801025
# NICE! Episode: 2, Timestep: 310, Reward: 95.52338839829015
# NICE! Episode: 2, Timestep: 316, Reward: 98.43900273570254
# NICE! Episode: 2, Timestep: 318, Reward: 99.11360113184924
# NICE! Episode: 2, Timestep: 319, Reward: 98.30411125785884
# NICE! Episode: 2, Timestep: 320, Reward: 96.80673881442303
# NICE! Episode: 2, Timestep: 321, Reward: 97.04272434851097
# NICE! Episode: 2, Timestep: 324, Reward: 98.23681490429529
# NICE! Episode: 2, Timestep: 325, Reward: 96.92014504721782
# NICE! Episode: 2, Timestep: 326, Reward: 98.63238736135538
# NICE! Episode: 2, Timestep: 328, Reward: 98.44829231426353
# NICE! Episode: 2, Timestep: 329, Reward: 99.11710458379285
# NICE! Episode: 2, Timestep: 333, Reward: 97.85847464495676
# NICE! Episode: 2, Timestep: 334, Reward: 98.19723419491933
# NICE! Episode: 2, Timestep: 336, Reward: 97.57704223742823
# NICE! Episode: 2, Timestep: 337, Reward: 97.43738257180154
# NICE! Episode: 2, Timestep: 339, Reward: 98.5970249453095
# NICE! Episode: 2, Timestep: 341, Reward: 98.64708162556533
# NICE! Episode: 2, Timestep: 342, Reward: 98.49854414095421
# NICE! Episode: 2, Timestep: 343, Reward: 98.87900791700595
# NICE! Episode: 2, Timestep: 346, Reward: 98.9948335788553
# NICE! Episode: 2, Timestep: 349, Reward: 96.88289940703412
# NICE! Episode: 2, Timestep: 350, Reward: 98.90684550406587
# NICE! Episode: 2, Timestep: 351, Reward: 98.7182797994277
# NICE! Episode: 2, Timestep: 352, Reward: 97.03328525318206
# NICE! Episode: 2, Timestep: 354, Reward: 97.0042728712705
# NICE! Episode: 2, Timestep: 356, Reward: 98.30336111499027
# NICE! Episode: 2, Timestep: 357, Reward: 98.23155692845863
# NICE! Episode: 2, Timestep: 358, Reward: 99.17903560529405
# NICE! Episode: 2, Timestep: 359, Reward: 97.8324928672027
# NICE! Episode: 2, Timestep: 360, Reward: 98.70167494981676
# NICE! Episode: 2, Timestep: 361, Reward: 97.54295904305702
# NICE! Episode: 2, Timestep: 362, Reward: 97.96199589096192
# NICE! Episode: 2, Timestep: 363, Reward: 97.668760088109
# NICE! Episode: 2, Timestep: 364, Reward: 99.37703434792046
# NICE! Episode: 2, Timestep: 365, Reward: 96.12522660519686
# NICE! Episode: 2, Timestep: 369, Reward: 99.35931730590565
# NICE! Episode: 2, Timestep: 371, Reward: 98.86710860616415
# NICE! Episode: 2, Timestep: 373, Reward: 98.08233067856736
# NICE! Episode: 2, Timestep: 374, Reward: 98.81150776810014
# NICE! Episode: 2, Timestep: 375, Reward: 99.08035617376434
# NICE! Episode: 2, Timestep: 378, Reward: 99.02441327289262
# NICE! Episode: 2, Timestep: 379, Reward: 97.47556720707286
# NICE! Episode: 2, Timestep: 382, Reward: 97.19267175475204
# NICE! Episode: 2, Timestep: 383, Reward: 98.55379146475131
# NICE! Episode: 2, Timestep: 384, Reward: 97.58968630936121
# NICE! Episode: 2, Timestep: 386, Reward: 98.23991559082704
# NICE! Episode: 2, Timestep: 387, Reward: 98.32914797070582
# NICE! Episode: 2, Timestep: 389, Reward: 98.20688033840838
# NICE! Episode: 2, Timestep: 390, Reward: 97.97251350539574
# NICE! Episode: 2, Timestep: 391, Reward: 98.67750332648406
# NICE! Episode: 2, Timestep: 392, Reward: 97.77049773013252
# NICE! Episode: 2, Timestep: 395, Reward: 97.4933205015704
# NICE! Episode: 2, Timestep: 396, Reward: 99.00114981479248
# NICE! Episode: 2, Timestep: 397, Reward: 98.31378117730372
# NICE! Episode: 2, Timestep: 398, Reward: 97.34131151521487
# TEST
# NICE! Episode: 3, Timestep: 0, Reward: 97.98616659268819
# NICE! Episode: 3, Timestep: 1, Reward: 97.9868366640831
# NICE! Episode: 3, Timestep: 2, Reward: 98.96990778768776
# NICE! Episode: 3, Timestep: 3, Reward: 97.73531533372301
# NICE! Episode: 3, Timestep: 4, Reward: 99.43525885352514
# NICE! Episode: 3, Timestep: 5, Reward: 99.27219155536552
# NICE! Episode: 3, Timestep: 6, Reward: 99.60513819794328
# NICE! Episode: 3, Timestep: 7, Reward: 99.61782274623242
# NICE! Episode: 3, Timestep: 8, Reward: 98.02026044593303
# NICE! Episode: 3, Timestep: 9, Reward: 99.4928928202042
# NICE! Episode: 3, Timestep: 10, Reward: 99.71924748208794
# NICE! Episode: 3, Timestep: 11, Reward: 99.40727408178034
# NICE! Episode: 3, Timestep: 12, Reward: 97.56716281592563
# NICE! Episode: 3, Timestep: 13, Reward: 98.83277632893329
# NICE! Episode: 3, Timestep: 14, Reward: 98.50882514487448
# NICE! Episode: 3, Timestep: 15, Reward: 97.41639749519902
# NICE! Episode: 3, Timestep: 17, Reward: 99.61999439663312
# NICE! Episode: 3, Timestep: 18, Reward: 99.72682733427995
# NICE! Episode: 3, Timestep: 19, Reward: 99.71001911106976
# NICE! Episode: 3, Timestep: 20, Reward: 97.97020564609686
# NICE! Episode: 3, Timestep: 21, Reward: 99.5158047339435
# NICE! Episode: 3, Timestep: 22, Reward: 97.39359320909122
# NICE! Episode: 3, Timestep: 24, Reward: 99.69637203956869
# NICE! Episode: 3, Timestep: 25, Reward: 99.7848259559947
# NICE! Episode: 3, Timestep: 26, Reward: 99.64489269527044
# NICE! Episode: 3, Timestep: 27, Reward: 98.28446550590162
# NICE! Episode: 3, Timestep: 29, Reward: 98.77362916472585
# NICE! Episode: 3, Timestep: 30, Reward: 99.09611014252711
# NICE! Episode: 3, Timestep: 31, Reward: 99.722904355194
# NICE! Episode: 3, Timestep: 34, Reward: 99.57852497328497
# NICE! Episode: 3, Timestep: 35, Reward: 99.69258894387619
# NICE! Episode: 3, Timestep: 36, Reward: 99.18799866978063
# NICE! Episode: 3, Timestep: 37, Reward: 97.7993425525911
# NICE! Episode: 3, Timestep: 40, Reward: 99.67498140153185
# NICE! Episode: 3, Timestep: 41, Reward: 99.79587659237338
# NICE! Episode: 3, Timestep: 42, Reward: 99.52873012618699
# NICE! Episode: 3, Timestep: 45, Reward: 99.35402566609748
# NICE! Episode: 3, Timestep: 47, Reward: 99.78581203256203
# NICE! Episode: 3, Timestep: 48, Reward: 99.04829716429361
# NICE! Episode: 3, Timestep: 49, Reward: 97.6448494047972
# NICE! Episode: 3, Timestep: 51, Reward: 99.58677326721417
# NICE! Episode: 3, Timestep: 52, Reward: 98.4371033239496
# NICE! Episode: 3, Timestep: 53, Reward: 97.85070306632818
# NICE! Episode: 3, Timestep: 54, Reward: 97.95580878772702
# NICE! Episode: 3, Timestep: 55, Reward: 99.43509402074646
# NICE! Episode: 3, Timestep: 56, Reward: 98.9707506469636
# NICE! Episode: 3, Timestep: 57, Reward: 99.7024178568694
# NICE! Episode: 3, Timestep: 58, Reward: 99.23483879613778
# NICE! Episode: 3, Timestep: 59, Reward: 98.96333397958377
# NICE! Episode: 3, Timestep: 60, Reward: 99.05853996485716
# NICE! Episode: 3, Timestep: 61, Reward: 96.98109638819994
# NICE! Episode: 3, Timestep: 62, Reward: 99.28439605852468
# NICE! Episode: 3, Timestep: 63, Reward: 99.82168644911798
# NICE! Episode: 3, Timestep: 64, Reward: 98.94477585006813
# NICE! Episode: 3, Timestep: 65, Reward: 99.77849524123498
# NICE! Episode: 3, Timestep: 66, Reward: 98.5335211713038
# NICE! Episode: 3, Timestep: 67, Reward: 99.40086281295984
# NICE! Episode: 3, Timestep: 69, Reward: 99.55114433667079
# NICE! Episode: 3, Timestep: 70, Reward: 99.49441519232036
# NICE! Episode: 3, Timestep: 71, Reward: 99.53434634390554
# NICE! Episode: 3, Timestep: 72, Reward: 98.76076180796589
# NICE! Episode: 3, Timestep: 73, Reward: 98.3223291240203
# NICE! Episode: 3, Timestep: 74, Reward: 99.58650670831247
# NICE! Episode: 3, Timestep: 75, Reward: 97.66098319170653
# NICE! Episode: 3, Timestep: 76, Reward: 99.42611600206469
# NICE! Episode: 3, Timestep: 77, Reward: 97.78986035157006
# NICE! Episode: 3, Timestep: 78, Reward: 99.74024916777957
# NICE! Episode: 3, Timestep: 79, Reward: 99.83027327685755
# NICE! Episode: 3, Timestep: 80, Reward: 99.51247040454521
# NICE! Episode: 3, Timestep: 81, Reward: 97.67309859904813
# NICE! Episode: 3, Timestep: 82, Reward: 99.5635374169266
# NICE! Episode: 3, Timestep: 83, Reward: 99.03927167079706
# NICE! Episode: 3, Timestep: 84, Reward: 99.65436184839402
# NICE! Episode: 3, Timestep: 85, Reward: 99.38328947304487
# NICE! Episode: 3, Timestep: 89, Reward: 99.77250232640237
# NICE! Episode: 3, Timestep: 90, Reward: 99.50085725919415
# NICE! Episode: 3, Timestep: 91, Reward: 99.03150198452386
# NICE! Episode: 3, Timestep: 92, Reward: 98.07071865858751
# NICE! Episode: 3, Timestep: 94, Reward: 98.31495289080799
# NICE! Episode: 3, Timestep: 95, Reward: 99.54016591850436
# NICE! Episode: 3, Timestep: 97, Reward: 98.627812551769
# NICE! Episode: 3, Timestep: 98, Reward: 98.13737754135097
# NICE! Episode: 3, Timestep: 99, Reward: 99.70540938649346
# NICE! Episode: 3, Timestep: 100, Reward: 99.74048645926807
# NICE! Episode: 3, Timestep: 101, Reward: 98.51021731727076
# NICE! Episode: 3, Timestep: 102, Reward: 98.65392421218587
# NICE! Episode: 3, Timestep: 103, Reward: 99.1299416771747
# NICE! Episode: 3, Timestep: 105, Reward: 98.83967101103006
# NICE! Episode: 3, Timestep: 106, Reward: 97.86834959456961
# NICE! Episode: 3, Timestep: 107, Reward: 99.72801305426361
# NICE! Episode: 3, Timestep: 108, Reward: 99.77575525335178
# NICE! Episode: 3, Timestep: 109, Reward: 98.52617692118295
# NICE! Episode: 3, Timestep: 110, Reward: 99.67613557229849
# NICE! Episode: 3, Timestep: 111, Reward: 98.76089389868108
# NICE! Episode: 3, Timestep: 112, Reward: 99.80251305269347
# NICE! Episode: 3, Timestep: 113, Reward: 98.6807993792579
# NICE! Episode: 3, Timestep: 114, Reward: 99.87604529348943
# NICE! Episode: 3, Timestep: 115, Reward: 99.78394470172823
# NICE! Episode: 3, Timestep: 117, Reward: 99.69859019421354
# NICE! Episode: 3, Timestep: 119, Reward: 98.75314985390237
# NICE! Episode: 3, Timestep: 123, Reward: 99.88644745055936
# NICE! Episode: 3, Timestep: 124, Reward: 98.97681181956874
# NICE! Episode: 3, Timestep: 127, Reward: 99.78862143773237
# NICE! Episode: 3, Timestep: 129, Reward: 99.82747138611387
# NICE! Episode: 3, Timestep: 130, Reward: 99.53248902962247
# NICE! Episode: 3, Timestep: 132, Reward: 99.82751518093225
# NICE! Episode: 3, Timestep: 133, Reward: 98.06044315718306
# NICE! Episode: 3, Timestep: 134, Reward: 99.79886951202444
# NICE! Episode: 3, Timestep: 135, Reward: 99.62200092110301
# NICE! Episode: 3, Timestep: 137, Reward: 98.72546393572836
# NICE! Episode: 3, Timestep: 138, Reward: 98.69438145164861
# NICE! Episode: 3, Timestep: 139, Reward: 99.48594455223584
# NICE! Episode: 3, Timestep: 140, Reward: 99.20654024456034
# NICE! Episode: 3, Timestep: 141, Reward: 99.37631794489722
# NICE! Episode: 3, Timestep: 142, Reward: 99.30118109379367
# NICE! Episode: 3, Timestep: 144, Reward: 99.46102618572297
# NICE! Episode: 3, Timestep: 145, Reward: 99.46367707599528
# NICE! Episode: 3, Timestep: 147, Reward: 97.85541184405727
# NICE! Episode: 3, Timestep: 149, Reward: 99.54368443900077
# NICE! Episode: 3, Timestep: 150, Reward: 97.86806388353806
# NICE! Episode: 3, Timestep: 151, Reward: 99.48294242061911
# NICE! Episode: 3, Timestep: 152, Reward: 99.5904671722906
# NICE! Episode: 3, Timestep: 153, Reward: 99.49953893086557
# NICE! Episode: 3, Timestep: 154, Reward: 98.37699990697104
# NICE! Episode: 3, Timestep: 155, Reward: 99.8506880976282
# NICE! Episode: 3, Timestep: 156, Reward: 98.70863215455039
# NICE! Episode: 3, Timestep: 157, Reward: 99.59229488857511
# NICE! Episode: 3, Timestep: 159, Reward: 99.11881068393804
# NICE! Episode: 3, Timestep: 161, Reward: 99.62633919733004
# NICE! Episode: 3, Timestep: 162, Reward: 98.41703078145588
# NICE! Episode: 3, Timestep: 163, Reward: 97.96331171589797
# NICE! Episode: 3, Timestep: 164, Reward: 99.12023991693967
# NICE! Episode: 3, Timestep: 166, Reward: 97.47474571320842
# NICE! Episode: 3, Timestep: 167, Reward: 99.81914169836269
# NICE! Episode: 3, Timestep: 168, Reward: 99.77880025073557
# NICE! Episode: 3, Timestep: 170, Reward: 99.59356092956743
# NICE! Episode: 3, Timestep: 171, Reward: 99.25866242924027
# NICE! Episode: 3, Timestep: 172, Reward: 99.69281986461415
# NICE! Episode: 3, Timestep: 173, Reward: 98.41498564021875
# NICE! Episode: 3, Timestep: 174, Reward: 99.20821737323448
# NICE! Episode: 3, Timestep: 175, Reward: 98.1407933868795
# NICE! Episode: 3, Timestep: 178, Reward: 99.39969488833461
# NICE! Episode: 3, Timestep: 179, Reward: 99.40908858902759
# NICE! Episode: 3, Timestep: 180, Reward: 98.06241165611648
# NICE! Episode: 3, Timestep: 182, Reward: 99.77065259821971
# NICE! Episode: 3, Timestep: 184, Reward: 99.8545674761007
# NICE! Episode: 3, Timestep: 185, Reward: 99.43192846363034
# NICE! Episode: 3, Timestep: 186, Reward: 99.77570310494701
# NICE! Episode: 3, Timestep: 187, Reward: 99.44545102264321
# NICE! Episode: 3, Timestep: 188, Reward: 98.00345563704852
# NICE! Episode: 3, Timestep: 190, Reward: 99.02309406921482
# NICE! Episode: 3, Timestep: 191, Reward: 99.36977873391366
# NICE! Episode: 3, Timestep: 192, Reward: 99.52113193258026
# NICE! Episode: 3, Timestep: 193, Reward: 99.64023091517721
# NICE! Episode: 3, Timestep: 194, Reward: 99.7680860340556
# NICE! Episode: 3, Timestep: 195, Reward: 99.4430884010991
# NICE! Episode: 3, Timestep: 197, Reward: 99.7515652992389
# NICE! Episode: 3, Timestep: 198, Reward: 99.79102986538176
# NICE! Episode: 3, Timestep: 199, Reward: 98.88379823489039
# NICE! Episode: 3, Timestep: 200, Reward: 99.73820497552443
# NICE! Episode: 3, Timestep: 201, Reward: 99.74703553446814
# NICE! Episode: 3, Timestep: 202, Reward: 99.3297746156228
# NICE! Episode: 3, Timestep: 204, Reward: 99.61222391613519
# NICE! Episode: 3, Timestep: 205, Reward: 99.57282486658893
# NICE! Episode: 3, Timestep: 206, Reward: 98.81713419377401
# NICE! Episode: 3, Timestep: 208, Reward: 98.5294597820075
# NICE! Episode: 3, Timestep: 209, Reward: 99.71509842168082
# NICE! Episode: 3, Timestep: 211, Reward: 98.80345446275224
# NICE! Episode: 3, Timestep: 212, Reward: 99.78573587444438
# NICE! Episode: 3, Timestep: 213, Reward: 99.38228389902045
# NICE! Episode: 3, Timestep: 215, Reward: 98.38477557940907
# NICE! Episode: 3, Timestep: 216, Reward: 99.90645166938621
# NICE! Episode: 3, Timestep: 217, Reward: 97.88271029588412
# NICE! Episode: 3, Timestep: 218, Reward: 99.7230550313636
# NICE! Episode: 3, Timestep: 219, Reward: 99.26469666584234
# NICE! Episode: 3, Timestep: 220, Reward: 99.16352229866564
# NICE! Episode: 3, Timestep: 221, Reward: 98.08597862492411
# NICE! Episode: 3, Timestep: 223, Reward: 99.56811576060771
# NICE! Episode: 3, Timestep: 224, Reward: 99.77155583334346
# NICE! Episode: 3, Timestep: 225, Reward: 98.66351329789981
# NICE! Episode: 3, Timestep: 226, Reward: 99.71600750872281
# NICE! Episode: 3, Timestep: 227, Reward: 99.6405174235326
# NICE! Episode: 3, Timestep: 228, Reward: 99.56371990069931
# NICE! Episode: 3, Timestep: 233, Reward: 99.43361782652278
# NICE! Episode: 3, Timestep: 234, Reward: 99.77466864119268
# NICE! Episode: 3, Timestep: 236, Reward: 99.61261391407209
# NICE! Episode: 3, Timestep: 237, Reward: 97.45969441960982
# NICE! Episode: 3, Timestep: 238, Reward: 99.32041142572683
# NICE! Episode: 3, Timestep: 239, Reward: 99.2622846397566
# NICE! Episode: 3, Timestep: 240, Reward: 99.48760702973188
# NICE! Episode: 3, Timestep: 241, Reward: 99.66928801364712
# NICE! Episode: 3, Timestep: 242, Reward: 99.22209884843174
# NICE! Episode: 3, Timestep: 243, Reward: 99.64986609363675
# NICE! Episode: 3, Timestep: 244, Reward: 99.32878253635387
# NICE! Episode: 3, Timestep: 246, Reward: 96.64810509329148
# NICE! Episode: 3, Timestep: 247, Reward: 99.36789320247988
# NICE! Episode: 3, Timestep: 248, Reward: 99.61595028869826
# NICE! Episode: 3, Timestep: 250, Reward: 99.62155674490607
# NICE! Episode: 3, Timestep: 251, Reward: 99.40331029814988
# NICE! Episode: 3, Timestep: 253, Reward: 98.45795840237791
# NICE! Episode: 3, Timestep: 254, Reward: 99.00701389312874
# NICE! Episode: 3, Timestep: 255, Reward: 99.47001828564562
# NICE! Episode: 3, Timestep: 256, Reward: 99.21357085943377
# NICE! Episode: 3, Timestep: 257, Reward: 99.17315428387307
# NICE! Episode: 3, Timestep: 259, Reward: 99.61665425586345
# NICE! Episode: 3, Timestep: 260, Reward: 98.89164083185624
# NICE! Episode: 3, Timestep: 261, Reward: 99.70592872691235
# NICE! Episode: 3, Timestep: 262, Reward: 99.16586948588646
# NICE! Episode: 3, Timestep: 263, Reward: 99.68591011465911
# NICE! Episode: 3, Timestep: 264, Reward: 99.50893779010455
# NICE! Episode: 3, Timestep: 266, Reward: 97.3793271132368
# NICE! Episode: 3, Timestep: 267, Reward: 99.81045056896787
# NICE! Episode: 3, Timestep: 268, Reward: 98.38271424129432
# NICE! Episode: 3, Timestep: 269, Reward: 99.12224398990965
# NICE! Episode: 3, Timestep: 270, Reward: 99.22469236897187
# NICE! Episode: 3, Timestep: 273, Reward: 99.46133143825926
# NICE! Episode: 3, Timestep: 278, Reward: 99.29983128673794
# NICE! Episode: 3, Timestep: 279, Reward: 99.69651613256983
# NICE! Episode: 3, Timestep: 280, Reward: 99.24331122073087
# NICE! Episode: 3, Timestep: 281, Reward: 98.86418767893615
# NICE! Episode: 3, Timestep: 282, Reward: 99.61247557946324
# NICE! Episode: 3, Timestep: 283, Reward: 99.7482211988034
# NICE! Episode: 3, Timestep: 284, Reward: 99.74146723348649
# NICE! Episode: 3, Timestep: 285, Reward: 98.58000950615131
# NICE! Episode: 3, Timestep: 286, Reward: 99.71420441770546
# NICE! Episode: 3, Timestep: 287, Reward: 99.26184449812219
# NICE! Episode: 3, Timestep: 288, Reward: 98.75511808758523
# NICE! Episode: 3, Timestep: 290, Reward: 99.2767870860175
# NICE! Episode: 3, Timestep: 291, Reward: 98.51660472390847
# NICE! Episode: 3, Timestep: 292, Reward: 98.91503541336891
# NICE! Episode: 3, Timestep: 294, Reward: 98.59324721423421
# NICE! Episode: 3, Timestep: 296, Reward: 99.75403738281008
# NICE! Episode: 3, Timestep: 298, Reward: 99.10872278575889
# NICE! Episode: 3, Timestep: 300, Reward: 99.19309396284581
# NICE! Episode: 3, Timestep: 302, Reward: 99.4298997820958
# NICE! Episode: 3, Timestep: 303, Reward: 99.50519409767905
# NICE! Episode: 3, Timestep: 305, Reward: 99.83169283982923
# NICE! Episode: 3, Timestep: 306, Reward: 98.98121757490954
# NICE! Episode: 3, Timestep: 307, Reward: 99.58816263242421
# NICE! Episode: 3, Timestep: 308, Reward: 98.61354269589634
# NICE! Episode: 3, Timestep: 309, Reward: 99.20175832134053
# NICE! Episode: 3, Timestep: 310, Reward: 99.10050258007732
# NICE! Episode: 3, Timestep: 312, Reward: 99.38518752863402
# NICE! Episode: 3, Timestep: 313, Reward: 99.19129985713919
# NICE! Episode: 3, Timestep: 314, Reward: 99.1603315987293
# NICE! Episode: 3, Timestep: 315, Reward: 99.57885827545635
# NICE! Episode: 3, Timestep: 316, Reward: 99.34820479649984
# NICE! Episode: 3, Timestep: 317, Reward: 99.30653859295569
# NICE! Episode: 3, Timestep: 318, Reward: 99.37678378424485
# NICE! Episode: 3, Timestep: 320, Reward: 99.41989493445212
# NICE! Episode: 3, Timestep: 322, Reward: 99.22760543892028
# NICE! Episode: 3, Timestep: 323, Reward: 99.13854664148364
# NICE! Episode: 3, Timestep: 324, Reward: 98.55273085564325
# NICE! Episode: 3, Timestep: 325, Reward: 99.75121967388952
# NICE! Episode: 3, Timestep: 326, Reward: 99.55241671387721
# NICE! Episode: 3, Timestep: 327, Reward: 99.40599844707951
# NICE! Episode: 3, Timestep: 330, Reward: 98.33923836899561
# NICE! Episode: 3, Timestep: 332, Reward: 99.5368937313714
# NICE! Episode: 3, Timestep: 333, Reward: 99.50581541172551
# NICE! Episode: 3, Timestep: 334, Reward: 99.5280723958239
# NICE! Episode: 3, Timestep: 336, Reward: 99.48809533274971
# NICE! Episode: 3, Timestep: 337, Reward: 99.55966433346714
# NICE! Episode: 3, Timestep: 338, Reward: 99.15778964052812
# NICE! Episode: 3, Timestep: 339, Reward: 99.65185911647849
# NICE! Episode: 3, Timestep: 340, Reward: 98.85845412486282
# NICE! Episode: 3, Timestep: 341, Reward: 99.48464422203077
# NICE! Episode: 3, Timestep: 342, Reward: 98.92506178809568
# NICE! Episode: 3, Timestep: 343, Reward: 99.53713160119823
# NICE! Episode: 3, Timestep: 344, Reward: 99.10889643170435
# NICE! Episode: 3, Timestep: 345, Reward: 98.88733879376029
# NICE! Episode: 3, Timestep: 346, Reward: 99.08461636229634
# NICE! Episode: 3, Timestep: 347, Reward: 99.09392861825759
# NICE! Episode: 3, Timestep: 348, Reward: 99.56964613730999
# NICE! Episode: 3, Timestep: 349, Reward: 99.69836888947292
# NICE! Episode: 3, Timestep: 350, Reward: 99.44500333080292
# NICE! Episode: 3, Timestep: 353, Reward: 98.09891301820775
# NICE! Episode: 3, Timestep: 355, Reward: 98.17035070365253
# NICE! Episode: 3, Timestep: 356, Reward: 97.93165750025307
# NICE! Episode: 3, Timestep: 357, Reward: 99.23225773546534
# NICE! Episode: 3, Timestep: 358, Reward: 99.2779708963972
# NICE! Episode: 3, Timestep: 359, Reward: 99.19670621771974
# NICE! Episode: 3, Timestep: 360, Reward: 99.68199835745139
# NICE! Episode: 3, Timestep: 361, Reward: 99.74310033295046
# NICE! Episode: 3, Timestep: 362, Reward: 99.58663065348681
# NICE! Episode: 3, Timestep: 363, Reward: 99.67832306703234
# NICE! Episode: 3, Timestep: 364, Reward: 99.22334418290332
# NICE! Episode: 3, Timestep: 365, Reward: 99.6144156655061
# NICE! Episode: 3, Timestep: 366, Reward: 99.29320434256633
# NICE! Episode: 3, Timestep: 367, Reward: 98.35586351508631
# NICE! Episode: 3, Timestep: 368, Reward: 99.57086854477507
# NICE! Episode: 3, Timestep: 369, Reward: 99.83626128928017
# NICE! Episode: 3, Timestep: 371, Reward: 99.82811046251857
# NICE! Episode: 3, Timestep: 372, Reward: 99.84519593451768
# NICE! Episode: 3, Timestep: 373, Reward: 99.51098900918102
# NICE! Episode: 3, Timestep: 374, Reward: 98.91066743384555
# NICE! Episode: 3, Timestep: 376, Reward: 99.82482778057373
# NICE! Episode: 3, Timestep: 377, Reward: 99.60109030633213
# NICE! Episode: 3, Timestep: 378, Reward: 99.65806162838776
# NICE! Episode: 3, Timestep: 379, Reward: 99.87069997223233
# NICE! Episode: 3, Timestep: 380, Reward: 99.56593847941905
# NICE! Episode: 3, Timestep: 381, Reward: 99.60724712624575
# NICE! Episode: 3, Timestep: 382, Reward: 98.53603849468142
# NICE! Episode: 3, Timestep: 384, Reward: 99.62256014922359
# NICE! Episode: 3, Timestep: 385, Reward: 99.37320115078136
# NICE! Episode: 3, Timestep: 386, Reward: 99.73377796302243
# NICE! Episode: 3, Timestep: 387, Reward: 99.78224618564819
# NICE! Episode: 3, Timestep: 388, Reward: 98.80902628455415
# NICE! Episode: 3, Timestep: 389, Reward: 97.74267027573231
# NICE! Episode: 3, Timestep: 390, Reward: 99.61091851913842
# NICE! Episode: 3, Timestep: 391, Reward: 99.81801707793754
# NICE! Episode: 3, Timestep: 392, Reward: 99.8021255772435
# NICE! Episode: 3, Timestep: 393, Reward: 99.32143228116375
# NICE! Episode: 3, Timestep: 394, Reward: 97.76503649002467
# NICE! Episode: 3, Timestep: 397, Reward: 99.64651466408834
# NICE! Episode: 3, Timestep: 398, Reward: 99.63193077276594
# TEST
# NICE! Episode: 4, Timestep: 1, Reward: 98.50157745500168
# NICE! Episode: 4, Timestep: 23, Reward: 97.97275822850382
# NICE! Episode: 4, Timestep: 38, Reward: 97.07749240736403
# NICE! Episode: 4, Timestep: 45, Reward: 97.94034127555481
# NICE! Episode: 4, Timestep: 59, Reward: 98.69569179606854
# NICE! Episode: 4, Timestep: 61, Reward: 98.87938716165885
# NICE! Episode: 4, Timestep: 107, Reward: 97.96995779169029
# NICE! Episode: 4, Timestep: 124, Reward: 97.80940463767178
# NICE! Episode: 4, Timestep: 136, Reward: 98.06510694250555
# NICE! Episode: 4, Timestep: 169, Reward: 98.61326229905161
# NICE! Episode: 4, Timestep: 181, Reward: 98.18391906807312
# NICE! Episode: 4, Timestep: 205, Reward: 98.69723095624347
# NICE! Episode: 4, Timestep: 224, Reward: 97.02486352863427
# NICE! Episode: 4, Timestep: 334, Reward: 98.54373103594499
# NICE! Episode: 4, Timestep: 344, Reward: 98.67219889719414
# NICE! Episode: 4, Timestep: 378, Reward: 99.079106928702
# TEST
# NICE! Episode: 5, Timestep: 3, Reward: 98.27206242598344
# NICE! Episode: 5, Timestep: 5, Reward: 97.85970656707484
# NICE! Episode: 5, Timestep: 11, Reward: 97.39165768807842
# NICE! Episode: 5, Timestep: 14, Reward: 98.20425285843739
# NICE! Episode: 5, Timestep: 20, Reward: 98.22055542266915
# NICE! Episode: 5, Timestep: 23, Reward: 98.44436044195184
# NICE! Episode: 5, Timestep: 24, Reward: 98.80804881028313
# NICE! Episode: 5, Timestep: 26, Reward: 98.21446555303332
# NICE! Episode: 5, Timestep: 32, Reward: 97.63053651635562
# NICE! Episode: 5, Timestep: 35, Reward: 97.09096323378101
# NICE! Episode: 5, Timestep: 37, Reward: 97.87468338225193
# NICE! Episode: 5, Timestep: 40, Reward: 99.13341491877341
# NICE! Episode: 5, Timestep: 44, Reward: 98.27390570109856
# NICE! Episode: 5, Timestep: 46, Reward: 98.04887656754724
# NICE! Episode: 5, Timestep: 60, Reward: 97.63944901976748
# NICE! Episode: 5, Timestep: 66, Reward: 97.79401348958247
# NICE! Episode: 5, Timestep: 67, Reward: 98.00526873695516
# NICE! Episode: 5, Timestep: 70, Reward: 98.87064681525429
# NICE! Episode: 5, Timestep: 71, Reward: 97.72198255280054
# NICE! Episode: 5, Timestep: 73, Reward: 98.05198719479206
# NICE! Episode: 5, Timestep: 80, Reward: 99.0428660149877
# NICE! Episode: 5, Timestep: 82, Reward: 97.87687754244779
# NICE! Episode: 5, Timestep: 97, Reward: 98.84281248018726
# NICE! Episode: 5, Timestep: 99, Reward: 97.0161994715123
# NICE! Episode: 5, Timestep: 101, Reward: 96.65962694479839
# NICE! Episode: 5, Timestep: 109, Reward: 96.78716320550727
# NICE! Episode: 5, Timestep: 110, Reward: 98.49184172832801
# NICE! Episode: 5, Timestep: 111, Reward: 96.69875183395885
# NICE! Episode: 5, Timestep: 113, Reward: 97.09224787127073
# NICE! Episode: 5, Timestep: 119, Reward: 97.90075700081162
# NICE! Episode: 5, Timestep: 121, Reward: 97.51609821795935
# NICE! Episode: 5, Timestep: 125, Reward: 98.19228246771455
# NICE! Episode: 5, Timestep: 128, Reward: 98.77734247506972
# NICE! Episode: 5, Timestep: 132, Reward: 98.90263086686149
# NICE! Episode: 5, Timestep: 138, Reward: 98.66381899417081
# NICE! Episode: 5, Timestep: 141, Reward: 98.4335597586012
# NICE! Episode: 5, Timestep: 142, Reward: 97.92380045777828
# NICE! Episode: 5, Timestep: 143, Reward: 97.93171348384367
# NICE! Episode: 5, Timestep: 147, Reward: 98.58616450590706
# NICE! Episode: 5, Timestep: 151, Reward: 98.79989887300866
# NICE! Episode: 5, Timestep: 160, Reward: 98.14740896392719
# NICE! Episode: 5, Timestep: 164, Reward: 97.51922203491131
# NICE! Episode: 5, Timestep: 169, Reward: 97.77133893370936
# NICE! Episode: 5, Timestep: 173, Reward: 98.48280658848549
# NICE! Episode: 5, Timestep: 175, Reward: 98.23638074130012
# NICE! Episode: 5, Timestep: 176, Reward: 97.88432081235453
# NICE! Episode: 5, Timestep: 178, Reward: 98.42520960855065
# NICE! Episode: 5, Timestep: 179, Reward: 96.93089279874059
# NICE! Episode: 5, Timestep: 181, Reward: 97.9125188425924
# NICE! Episode: 5, Timestep: 182, Reward: 98.56843530155196
# NICE! Episode: 5, Timestep: 183, Reward: 98.68597549923047
# NICE! Episode: 5, Timestep: 184, Reward: 98.26426523160833
# NICE! Episode: 5, Timestep: 189, Reward: 98.84506563421868
# NICE! Episode: 5, Timestep: 191, Reward: 98.7113491898968
# NICE! Episode: 5, Timestep: 192, Reward: 97.7733912398908
# NICE! Episode: 5, Timestep: 195, Reward: 96.60534247774842
# NICE! Episode: 5, Timestep: 197, Reward: 98.88638438961443
# NICE! Episode: 5, Timestep: 199, Reward: 97.97734494436733
# NICE! Episode: 5, Timestep: 201, Reward: 97.51277395502034
# NICE! Episode: 5, Timestep: 206, Reward: 98.76228998955854
# NICE! Episode: 5, Timestep: 208, Reward: 96.97496967294208
# NICE! Episode: 5, Timestep: 209, Reward: 98.30341610760989
# NICE! Episode: 5, Timestep: 212, Reward: 98.36288699640254
# NICE! Episode: 5, Timestep: 215, Reward: 97.47862851584395
# NICE! Episode: 5, Timestep: 216, Reward: 98.21844654086014
# NICE! Episode: 5, Timestep: 221, Reward: 97.60693238703392
# NICE! Episode: 5, Timestep: 224, Reward: 97.47630657742697
# NICE! Episode: 5, Timestep: 226, Reward: 98.37493210059127
# NICE! Episode: 5, Timestep: 229, Reward: 98.0277252074871
# NICE! Episode: 5, Timestep: 232, Reward: 98.82938747408157
# NICE! Episode: 5, Timestep: 239, Reward: 98.58262350140996
# NICE! Episode: 5, Timestep: 240, Reward: 96.95012968165705
# NICE! Episode: 5, Timestep: 242, Reward: 98.77719132286676
# NICE! Episode: 5, Timestep: 247, Reward: 97.61669550944974
# NICE! Episode: 5, Timestep: 251, Reward: 97.11795905037361
# NICE! Episode: 5, Timestep: 256, Reward: 98.62014755287714
# NICE! Episode: 5, Timestep: 260, Reward: 98.10342707785273
# NICE! Episode: 5, Timestep: 262, Reward: 98.11698656079638
# NICE! Episode: 5, Timestep: 264, Reward: 97.95958230684802
# NICE! Episode: 5, Timestep: 266, Reward: 97.78177989078237
# NICE! Episode: 5, Timestep: 270, Reward: 98.21197649397477
# NICE! Episode: 5, Timestep: 274, Reward: 97.9294860396633
# NICE! Episode: 5, Timestep: 277, Reward: 97.98025887461196
# NICE! Episode: 5, Timestep: 282, Reward: 98.9734749074747
# NICE! Episode: 5, Timestep: 288, Reward: 98.52326475084122
# NICE! Episode: 5, Timestep: 289, Reward: 98.33751995287349
# NICE! Episode: 5, Timestep: 294, Reward: 98.64641514967516
# NICE! Episode: 5, Timestep: 298, Reward: 98.66053464371977
# NICE! Episode: 5, Timestep: 301, Reward: 97.09645715922566
# NICE! Episode: 5, Timestep: 302, Reward: 96.93202744826036
# NICE! Episode: 5, Timestep: 303, Reward: 97.73545259631693
# NICE! Episode: 5, Timestep: 304, Reward: 98.16890878612085
# NICE! Episode: 5, Timestep: 305, Reward: 97.44140543939363
# NICE! Episode: 5, Timestep: 314, Reward: 98.21197810336363
# NICE! Episode: 5, Timestep: 318, Reward: 98.04739468744772
# NICE! Episode: 5, Timestep: 319, Reward: 98.35759626269262
# NICE! Episode: 5, Timestep: 320, Reward: 96.69250053821472
# NICE! Episode: 5, Timestep: 322, Reward: 97.90726557832238
# NICE! Episode: 5, Timestep: 331, Reward: 97.49860803881538
# NICE! Episode: 5, Timestep: 332, Reward: 98.34047084195309
# NICE! Episode: 5, Timestep: 338, Reward: 97.85352094263881
# NICE! Episode: 5, Timestep: 339, Reward: 97.8247076385466
# NICE! Episode: 5, Timestep: 340, Reward: 99.01299806829016
# NICE! Episode: 5, Timestep: 342, Reward: 98.22064679317177
# NICE! Episode: 5, Timestep: 343, Reward: 97.15918592863794
# NICE! Episode: 5, Timestep: 344, Reward: 97.47086718255761
# NICE! Episode: 5, Timestep: 346, Reward: 98.2443029932544
# NICE! Episode: 5, Timestep: 347, Reward: 96.8415913201726
# NICE! Episode: 5, Timestep: 350, Reward: 98.40718642136537
# NICE! Episode: 5, Timestep: 353, Reward: 98.19505810566501
# NICE! Episode: 5, Timestep: 354, Reward: 97.54452419418024
# NICE! Episode: 5, Timestep: 361, Reward: 97.65852981258794
# NICE! Episode: 5, Timestep: 362, Reward: 98.20807561728148
# NICE! Episode: 5, Timestep: 363, Reward: 98.71779680325419
# NICE! Episode: 5, Timestep: 364, Reward: 95.89010296415854
# NICE! Episode: 5, Timestep: 365, Reward: 97.71321832484581
# NICE! Episode: 5, Timestep: 366, Reward: 97.56750897791635
# NICE! Episode: 5, Timestep: 367, Reward: 98.6120895327139
# NICE! Episode: 5, Timestep: 368, Reward: 99.00544491671465
# NICE! Episode: 5, Timestep: 370, Reward: 97.57345836907183
# NICE! Episode: 5, Timestep: 371, Reward: 98.19780126009151
# NICE! Episode: 5, Timestep: 373, Reward: 98.53798729142154
# NICE! Episode: 5, Timestep: 374, Reward: 98.26413798146413
# NICE! Episode: 5, Timestep: 375, Reward: 98.65544716642768
# NICE! Episode: 5, Timestep: 377, Reward: 98.01142463590814
# NICE! Episode: 5, Timestep: 378, Reward: 98.31740295424697
# NICE! Episode: 5, Timestep: 381, Reward: 98.16924435850687
# NICE! Episode: 5, Timestep: 382, Reward: 98.374602479934
# NICE! Episode: 5, Timestep: 383, Reward: 97.80235649468663
# NICE! Episode: 5, Timestep: 392, Reward: 98.34703849382339
# NICE! Episode: 5, Timestep: 398, Reward: 97.18927524167867
# TEST
# TEST
# NICE! Episode: 7, Timestep: 0, Reward: 98.99709498954628
# NICE! Episode: 7, Timestep: 3, Reward: 97.85507401020462
# NICE! Episode: 7, Timestep: 4, Reward: 99.74744565803115
# NICE! Episode: 7, Timestep: 5, Reward: 99.50059878530865
# NICE! Episode: 7, Timestep: 7, Reward: 99.00366801037246
# NICE! Episode: 7, Timestep: 8, Reward: 99.65891583124025
# NICE! Episode: 7, Timestep: 9, Reward: 99.56645711123012
# NICE! Episode: 7, Timestep: 10, Reward: 99.3870015577451
# NICE! Episode: 7, Timestep: 11, Reward: 99.8606598410326
# NICE! Episode: 7, Timestep: 12, Reward: 99.24435725146215
# NICE! Episode: 7, Timestep: 14, Reward: 98.75734671378612
# NICE! Episode: 7, Timestep: 15, Reward: 98.80114773326764
# NICE! Episode: 7, Timestep: 16, Reward: 99.30015384739522
# NICE! Episode: 7, Timestep: 17, Reward: 99.3664857505194
# NICE! Episode: 7, Timestep: 18, Reward: 99.24768504921548
# NICE! Episode: 7, Timestep: 21, Reward: 98.8593747981694
# NICE! Episode: 7, Timestep: 22, Reward: 98.28385671866819
# NICE! Episode: 7, Timestep: 23, Reward: 98.39376648209502
# NICE! Episode: 7, Timestep: 24, Reward: 99.42073760072756
# NICE! Episode: 7, Timestep: 25, Reward: 98.9357771271659
# NICE! Episode: 7, Timestep: 26, Reward: 98.69932515773444
# NICE! Episode: 7, Timestep: 28, Reward: 99.8264475224465
# NICE! Episode: 7, Timestep: 30, Reward: 98.01686293755725
# NICE! Episode: 7, Timestep: 31, Reward: 99.89368755049516
# NICE! Episode: 7, Timestep: 33, Reward: 99.78401669116609
# NICE! Episode: 7, Timestep: 34, Reward: 99.69487006202914
# NICE! Episode: 7, Timestep: 36, Reward: 99.8266371288192
# NICE! Episode: 7, Timestep: 37, Reward: 99.70076738180988
# NICE! Episode: 7, Timestep: 38, Reward: 98.56892339784211
# NICE! Episode: 7, Timestep: 39, Reward: 98.9457522687459
# NICE! Episode: 7, Timestep: 42, Reward: 99.47325647076681
# NICE! Episode: 7, Timestep: 43, Reward: 99.30175956064544
# NICE! Episode: 7, Timestep: 44, Reward: 98.355573530726
# NICE! Episode: 7, Timestep: 45, Reward: 99.04678633794093
# NICE! Episode: 7, Timestep: 46, Reward: 98.990510621017
# NICE! Episode: 7, Timestep: 49, Reward: 99.78845387251238
# NICE! Episode: 7, Timestep: 51, Reward: 99.61767935333954
# NICE! Episode: 7, Timestep: 53, Reward: 98.50720096040962
# NICE! Episode: 7, Timestep: 54, Reward: 99.55386490161683
# NICE! Episode: 7, Timestep: 55, Reward: 99.60166297104148
# NICE! Episode: 7, Timestep: 56, Reward: 99.3247080909186
# NICE! Episode: 7, Timestep: 57, Reward: 99.52143139085827
# NICE! Episode: 7, Timestep: 58, Reward: 98.57958984173123
# NICE! Episode: 7, Timestep: 59, Reward: 99.55813051449168
# NICE! Episode: 7, Timestep: 60, Reward: 99.05748221331244
# NICE! Episode: 7, Timestep: 62, Reward: 99.66711939631814
# NICE! Episode: 7, Timestep: 63, Reward: 99.75831133719973
# NICE! Episode: 7, Timestep: 65, Reward: 99.76773299771644
# NICE! Episode: 7, Timestep: 66, Reward: 99.58179371871172
# NICE! Episode: 7, Timestep: 69, Reward: 98.88853708583379
# NICE! Episode: 7, Timestep: 72, Reward: 99.3445716265553
# NICE! Episode: 7, Timestep: 73, Reward: 99.34289967986697
# NICE! Episode: 7, Timestep: 74, Reward: 99.45328101597028
# NICE! Episode: 7, Timestep: 75, Reward: 99.52617066009283
# NICE! Episode: 7, Timestep: 76, Reward: 99.38370621005205
# NICE! Episode: 7, Timestep: 78, Reward: 99.83880281067991
# NICE! Episode: 7, Timestep: 79, Reward: 99.44833435038876
# NICE! Episode: 7, Timestep: 80, Reward: 98.75995439634107
# NICE! Episode: 7, Timestep: 82, Reward: 99.78568898735207
# NICE! Episode: 7, Timestep: 83, Reward: 99.7331508052264
# NICE! Episode: 7, Timestep: 85, Reward: 99.09735007888833
# NICE! Episode: 7, Timestep: 86, Reward: 99.46891861905235
# NICE! Episode: 7, Timestep: 87, Reward: 99.32056646138554
# NICE! Episode: 7, Timestep: 88, Reward: 98.90674435877841
# NICE! Episode: 7, Timestep: 89, Reward: 98.05958836375451
# NICE! Episode: 7, Timestep: 91, Reward: 99.62219895453516
# NICE! Episode: 7, Timestep: 92, Reward: 99.51405095831059
# NICE! Episode: 7, Timestep: 93, Reward: 99.78702218373876
# NICE! Episode: 7, Timestep: 94, Reward: 99.67328745774822
# NICE! Episode: 7, Timestep: 95, Reward: 99.08185274611483
# NICE! Episode: 7, Timestep: 97, Reward: 99.81194587579184
# NICE! Episode: 7, Timestep: 98, Reward: 98.78882886545748
# NICE! Episode: 7, Timestep: 99, Reward: 99.04290021434767
# NICE! Episode: 7, Timestep: 100, Reward: 99.51045399673984
# NICE! Episode: 7, Timestep: 101, Reward: 98.20813201670468
# NICE! Episode: 7, Timestep: 103, Reward: 99.46536695724303
# NICE! Episode: 7, Timestep: 106, Reward: 99.72691948319797
# NICE! Episode: 7, Timestep: 107, Reward: 98.99114221805327
# NICE! Episode: 7, Timestep: 108, Reward: 99.83475547726067
# NICE! Episode: 7, Timestep: 110, Reward: 99.51911802770792
# NICE! Episode: 7, Timestep: 111, Reward: 99.37089693807451
# NICE! Episode: 7, Timestep: 114, Reward: 99.48789349170029
# NICE! Episode: 7, Timestep: 116, Reward: 99.64503283748175
# NICE! Episode: 7, Timestep: 117, Reward: 99.77767048292522
# NICE! Episode: 7, Timestep: 119, Reward: 98.46411832848233
# NICE! Episode: 7, Timestep: 120, Reward: 99.5566140666704
# NICE! Episode: 7, Timestep: 121, Reward: 99.81019003707735
# NICE! Episode: 7, Timestep: 123, Reward: 99.58775964326948
# NICE! Episode: 7, Timestep: 124, Reward: 99.55604063844692
# NICE! Episode: 7, Timestep: 125, Reward: 99.88326932703488
# NICE! Episode: 7, Timestep: 127, Reward: 99.50923617313649
# NICE! Episode: 7, Timestep: 129, Reward: 98.5692475160693
# NICE! Episode: 7, Timestep: 130, Reward: 99.24242598844286
# NICE! Episode: 7, Timestep: 131, Reward: 98.59626575717498
# NICE! Episode: 7, Timestep: 132, Reward: 98.88540716201643
# NICE! Episode: 7, Timestep: 133, Reward: 98.91818513764228
# NICE! Episode: 7, Timestep: 134, Reward: 99.22957859840683
# NICE! Episode: 7, Timestep: 135, Reward: 99.62539301177064
# NICE! Episode: 7, Timestep: 137, Reward: 99.59058931689142
# NICE! Episode: 7, Timestep: 138, Reward: 98.02834190627007
# NICE! Episode: 7, Timestep: 139, Reward: 98.89163871848561
# NICE! Episode: 7, Timestep: 140, Reward: 99.61667719694884
# NICE! Episode: 7, Timestep: 141, Reward: 99.46381114362627
# NICE! Episode: 7, Timestep: 142, Reward: 98.9617912096301
# NICE! Episode: 7, Timestep: 143, Reward: 99.91553515652505
# NICE! Episode: 7, Timestep: 144, Reward: 99.4578433944499
# NICE! Episode: 7, Timestep: 145, Reward: 99.68703822702703
# NICE! Episode: 7, Timestep: 146, Reward: 99.52912334218323
# NICE! Episode: 7, Timestep: 149, Reward: 99.54841212510016
# NICE! Episode: 7, Timestep: 150, Reward: 99.42110784770509
# NICE! Episode: 7, Timestep: 151, Reward: 98.70080123319387
# NICE! Episode: 7, Timestep: 152, Reward: 99.73424149539545
# NICE! Episode: 7, Timestep: 153, Reward: 98.43703874423139
# NICE! Episode: 7, Timestep: 155, Reward: 98.84341216709237
# NICE! Episode: 7, Timestep: 156, Reward: 99.73773217475282
# NICE! Episode: 7, Timestep: 157, Reward: 99.6927271916158
# NICE! Episode: 7, Timestep: 158, Reward: 99.6212504934104
# NICE! Episode: 7, Timestep: 159, Reward: 98.946948249712
# NICE! Episode: 7, Timestep: 161, Reward: 99.5555617803469
# NICE! Episode: 7, Timestep: 162, Reward: 98.96438722918826
# NICE! Episode: 7, Timestep: 163, Reward: 99.82011923596879
# NICE! Episode: 7, Timestep: 164, Reward: 99.83473318356347
# NICE! Episode: 7, Timestep: 165, Reward: 99.52174585855361
# NICE! Episode: 7, Timestep: 168, Reward: 99.8089321810063
# NICE! Episode: 7, Timestep: 169, Reward: 99.81352863396062
# NICE! Episode: 7, Timestep: 171, Reward: 99.72953230040213
# NICE! Episode: 7, Timestep: 172, Reward: 99.56533373620825
# NICE! Episode: 7, Timestep: 173, Reward: 99.51615450575756
# NICE! Episode: 7, Timestep: 174, Reward: 99.52901933303487
# NICE! Episode: 7, Timestep: 175, Reward: 99.82218086886799
# NICE! Episode: 7, Timestep: 176, Reward: 99.90416719644443
# NICE! Episode: 7, Timestep: 177, Reward: 99.649245651698
# NICE! Episode: 7, Timestep: 179, Reward: 99.86939082450354
# NICE! Episode: 7, Timestep: 180, Reward: 99.20980869899726
# NICE! Episode: 7, Timestep: 183, Reward: 99.73361349938703
# NICE! Episode: 7, Timestep: 184, Reward: 99.56529313745199
# ...
# NICE! Episode: 97, Timestep: 279, Reward: 99.69770694849491
# NICE! Episode: 97, Timestep: 280, Reward: 99.95683049107781
# NICE! Episode: 97, Timestep: 281, Reward: 99.68773214085599
# NICE! Episode: 97, Timestep: 282, Reward: 99.96305543156826
# NICE! Episode: 97, Timestep: 283, Reward: 99.85362617677097
# NICE! Episode: 97, Timestep: 284, Reward: 99.96910271338217
# NICE! Episode: 97, Timestep: 285, Reward: 99.86668493174922
# NICE! Episode: 97, Timestep: 286, Reward: 99.87877484273847
# NICE! Episode: 97, Timestep: 287, Reward: 99.92661223100366
# NICE! Episode: 97, Timestep: 288, Reward: 99.9369874747
# NICE! Episode: 97, Timestep: 289, Reward: 99.75767926861991
# NICE! Episode: 97, Timestep: 290, Reward: 99.59604992085627
# NICE! Episode: 97, Timestep: 291, Reward: 99.74812410775307
# NICE! Episode: 97, Timestep: 292, Reward: 99.90617282310849
# NICE! Episode: 97, Timestep: 293, Reward: 99.58648793846724
# NICE! Episode: 97, Timestep: 294, Reward: 99.95688395205616
# NICE! Episode: 97, Timestep: 295, Reward: 99.67016789135907
# NICE! Episode: 97, Timestep: 296, Reward: 99.87299436174125
# NICE! Episode: 97, Timestep: 297, Reward: 99.95702307039433
# NICE! Episode: 97, Timestep: 298, Reward: 99.88845754656947
# NICE! Episode: 97, Timestep: 299, Reward: 99.85414010870439
# NICE! Episode: 97, Timestep: 300, Reward: 99.84845047490036
# NICE! Episode: 97, Timestep: 301, Reward: 99.93646011956622
# NICE! Episode: 97, Timestep: 302, Reward: 99.6030267620439
# NICE! Episode: 97, Timestep: 303, Reward: 99.79443561901819
# NICE! Episode: 97, Timestep: 304, Reward: 99.95330372635023
# NICE! Episode: 97, Timestep: 305, Reward: 99.89494755699141
# NICE! Episode: 97, Timestep: 306, Reward: 99.9341530442272
# NICE! Episode: 97, Timestep: 307, Reward: 99.43080707145283
# NICE! Episode: 97, Timestep: 308, Reward: 99.8966616507136
# NICE! Episode: 97, Timestep: 309, Reward: 99.93355420777999
# NICE! Episode: 97, Timestep: 310, Reward: 99.60159443280786
# NICE! Episode: 97, Timestep: 312, Reward: 99.87820763219378
# NICE! Episode: 97, Timestep: 314, Reward: 99.75025694879643
# NICE! Episode: 97, Timestep: 316, Reward: 97.40161282731647
# NICE! Episode: 97, Timestep: 317, Reward: 99.55945983679358
# NICE! Episode: 97, Timestep: 319, Reward: 99.69396302056958
# NICE! Episode: 97, Timestep: 320, Reward: 97.87094577306968
# NICE! Episode: 97, Timestep: 322, Reward: 99.90572127153493
# NICE! Episode: 97, Timestep: 323, Reward: 99.93853199644556
# NICE! Episode: 97, Timestep: 324, Reward: 98.48610869010864
# NICE! Episode: 97, Timestep: 325, Reward: 99.9166508154733
# NICE! Episode: 97, Timestep: 326, Reward: 99.97529484113379
# NICE! Episode: 97, Timestep: 327, Reward: 99.88440887742823
# NICE! Episode: 97, Timestep: 329, Reward: 99.90320622401737
# NICE! Episode: 97, Timestep: 330, Reward: 99.97475653310107
# NICE! Episode: 97, Timestep: 331, Reward: 99.96002786214488
# NICE! Episode: 97, Timestep: 332, Reward: 99.72201109401475
# NICE! Episode: 97, Timestep: 333, Reward: 99.96974289676149
# NICE! Episode: 97, Timestep: 334, Reward: 99.77051577152751
# NICE! Episode: 97, Timestep: 336, Reward: 99.94582028387839
# NICE! Episode: 97, Timestep: 337, Reward: 98.60047343822096
# NICE! Episode: 97, Timestep: 338, Reward: 99.96949991857782
# NICE! Episode: 97, Timestep: 341, Reward: 99.30308436186886
# NICE! Episode: 97, Timestep: 342, Reward: 99.91616282325631
# NICE! Episode: 97, Timestep: 343, Reward: 99.64420087184631
# NICE! Episode: 97, Timestep: 344, Reward: 97.48582029075496
# NICE! Episode: 97, Timestep: 345, Reward: 99.84130800565302
# NICE! Episode: 97, Timestep: 347, Reward: 99.97106122249859
# NICE! Episode: 97, Timestep: 348, Reward: 99.80786670991229
# NICE! Episode: 97, Timestep: 349, Reward: 99.57837793710254
# NICE! Episode: 97, Timestep: 350, Reward: 99.93011828493583
# NICE! Episode: 97, Timestep: 351, Reward: 99.9660911888313
# NICE! Episode: 97, Timestep: 352, Reward: 99.5337030317872
# NICE! Episode: 97, Timestep: 353, Reward: 99.64849111435625
# NICE! Episode: 97, Timestep: 354, Reward: 99.88577246753611
# NICE! Episode: 97, Timestep: 355, Reward: 99.8320370988084
# NICE! Episode: 97, Timestep: 356, Reward: 99.88289239530395
# NICE! Episode: 97, Timestep: 357, Reward: 99.91678017193945
# NICE! Episode: 97, Timestep: 358, Reward: 99.94524464889861
# NICE! Episode: 97, Timestep: 360, Reward: 99.72895610530792
# NICE! Episode: 97, Timestep: 361, Reward: 99.87168371449809
# NICE! Episode: 97, Timestep: 362, Reward: 99.42511747437081
# NICE! Episode: 97, Timestep: 363, Reward: 99.96371429276914
# NICE! Episode: 97, Timestep: 364, Reward: 99.83770235279157
# NICE! Episode: 97, Timestep: 365, Reward: 99.40356540252434
# NICE! Episode: 97, Timestep: 366, Reward: 99.86370224829567
# NICE! Episode: 97, Timestep: 367, Reward: 99.83972936245709
# NICE! Episode: 97, Timestep: 368, Reward: 99.896632843219
# NICE! Episode: 97, Timestep: 369, Reward: 99.95781674580697
# NICE! Episode: 97, Timestep: 370, Reward: 99.78360100325862
# NICE! Episode: 97, Timestep: 371, Reward: 99.8573231767084
# NICE! Episode: 97, Timestep: 372, Reward: 99.92380933554874
# NICE! Episode: 97, Timestep: 373, Reward: 99.75936699450429
# NICE! Episode: 97, Timestep: 374, Reward: 99.87554094761894
# NICE! Episode: 97, Timestep: 375, Reward: 99.74103130429204
# NICE! Episode: 97, Timestep: 376, Reward: 99.81522098930338
# NICE! Episode: 97, Timestep: 378, Reward: 98.49048577329306
# NICE! Episode: 97, Timestep: 379, Reward: 99.88358848246146
# NICE! Episode: 97, Timestep: 380, Reward: 98.31049553058753
# NICE! Episode: 97, Timestep: 381, Reward: 99.82293426836827
# NICE! Episode: 97, Timestep: 382, Reward: 99.46749556641518
# NICE! Episode: 97, Timestep: 383, Reward: 99.92731366481587
# NICE! Episode: 97, Timestep: 384, Reward: 99.94949063016672
# NICE! Episode: 97, Timestep: 385, Reward: 99.96026458442854
# NICE! Episode: 97, Timestep: 386, Reward: 99.96740917132216
# NICE! Episode: 97, Timestep: 387, Reward: 99.77497917978624
# NICE! Episode: 97, Timestep: 388, Reward: 99.88614049521716
# NICE! Episode: 97, Timestep: 389, Reward: 99.79925585627623
# NICE! Episode: 97, Timestep: 390, Reward: 99.37132471723712
# NICE! Episode: 97, Timestep: 391, Reward: 99.88646757296162
# NICE! Episode: 97, Timestep: 392, Reward: 99.6646608279881
# NICE! Episode: 97, Timestep: 393, Reward: 99.73434846297079
# NICE! Episode: 97, Timestep: 394, Reward: 99.93584102230058
# NICE! Episode: 97, Timestep: 395, Reward: 99.81793510632579
# NICE! Episode: 97, Timestep: 396, Reward: 99.4872138855342
# NICE! Episode: 97, Timestep: 397, Reward: 99.9152936027767
# NICE! Episode: 97, Timestep: 398, Reward: 99.9577113588991
# TEST
# NICE! Episode: 98, Timestep: 0, Reward: 99.03605153888813
# NICE! Episode: 98, Timestep: 5, Reward: 99.73763381997087
# NICE! Episode: 98, Timestep: 8, Reward: 99.53898136680918
# NICE! Episode: 98, Timestep: 9, Reward: 98.78680909117972
# NICE! Episode: 98, Timestep: 12, Reward: 99.49771357048355
# NICE! Episode: 98, Timestep: 15, Reward: 99.09690452834138
# NICE! Episode: 98, Timestep: 17, Reward: 99.51530854829619
# NICE! Episode: 98, Timestep: 20, Reward: 99.0688894186683
# NICE! Episode: 98, Timestep: 21, Reward: 99.34021255980574
# NICE! Episode: 98, Timestep: 23, Reward: 99.36064463812355
# NICE! Episode: 98, Timestep: 33, Reward: 99.77663054825106
# NICE! Episode: 98, Timestep: 37, Reward: 98.72346073330839
# NICE! Episode: 98, Timestep: 38, Reward: 99.65229191123635
# NICE! Episode: 98, Timestep: 39, Reward: 99.72467019318168
# NICE! Episode: 98, Timestep: 40, Reward: 99.59366295596112
# NICE! Episode: 98, Timestep: 41, Reward: 98.56708171906823
# NICE! Episode: 98, Timestep: 42, Reward: 99.95063140410473
# NICE! Episode: 98, Timestep: 43, Reward: 99.84635568689748
# NICE! Episode: 98, Timestep: 45, Reward: 99.72848563198717
# NICE! Episode: 98, Timestep: 46, Reward: 99.72788261601077
# NICE! Episode: 98, Timestep: 47, Reward: 99.76307416355618
# NICE! Episode: 98, Timestep: 49, Reward: 99.69224071316425
# NICE! Episode: 98, Timestep: 50, Reward: 99.88225667276389
# NICE! Episode: 98, Timestep: 51, Reward: 98.50990831706001
# NICE! Episode: 98, Timestep: 53, Reward: 99.11129805713449
# NICE! Episode: 98, Timestep: 60, Reward: 99.2154498515946
# NICE! Episode: 98, Timestep: 63, Reward: 99.55044805390216
# NICE! Episode: 98, Timestep: 66, Reward: 99.17995919448742
# NICE! Episode: 98, Timestep: 67, Reward: 98.49543698577524
# NICE! Episode: 98, Timestep: 68, Reward: 97.95083429121917
# NICE! Episode: 98, Timestep: 69, Reward: 99.43249696545946
# NICE! Episode: 98, Timestep: 71, Reward: 99.41337428084964
# NICE! Episode: 98, Timestep: 73, Reward: 99.7216039486532
# NICE! Episode: 98, Timestep: 74, Reward: 98.9832333214391
# NICE! Episode: 98, Timestep: 75, Reward: 99.10440849347326
# NICE! Episode: 98, Timestep: 99, Reward: 97.76632889315768
# NICE! Episode: 98, Timestep: 102, Reward: 99.67920488468917
# NICE! Episode: 98, Timestep: 104, Reward: 99.3174149476673
# NICE! Episode: 98, Timestep: 110, Reward: 99.13098878744523
# NICE! Episode: 98, Timestep: 111, Reward: 98.32006434867905
# NICE! Episode: 98, Timestep: 124, Reward: 98.84253923265238
# NICE! Episode: 98, Timestep: 128, Reward: 99.23922583417051
# NICE! Episode: 98, Timestep: 129, Reward: 98.23458073106171
# NICE! Episode: 98, Timestep: 130, Reward: 99.68287737664363
# NICE! Episode: 98, Timestep: 131, Reward: 98.85245769471192
# NICE! Episode: 98, Timestep: 132, Reward: 99.01131750912204
# NICE! Episode: 98, Timestep: 134, Reward: 99.72107758374959
# NICE! Episode: 98, Timestep: 136, Reward: 98.94743190947356
# NICE! Episode: 98, Timestep: 138, Reward: 98.78204071746029
# NICE! Episode: 98, Timestep: 140, Reward: 99.54419867885879
# NICE! Episode: 98, Timestep: 141, Reward: 98.00191929520253
# NICE! Episode: 98, Timestep: 149, Reward: 99.24166905626087
# NICE! Episode: 98, Timestep: 154, Reward: 98.81237431795239
# NICE! Episode: 98, Timestep: 160, Reward: 99.40274683071014
# NICE! Episode: 98, Timestep: 161, Reward: 98.94562214829101
# NICE! Episode: 98, Timestep: 162, Reward: 99.6620048459889
# NICE! Episode: 98, Timestep: 163, Reward: 99.43124805182595
# NICE! Episode: 98, Timestep: 165, Reward: 98.5085543632699
# NICE! Episode: 98, Timestep: 166, Reward: 98.91908433604941
# NICE! Episode: 98, Timestep: 168, Reward: 99.56433757003812
# NICE! Episode: 98, Timestep: 169, Reward: 99.9673834510437
# NICE! Episode: 98, Timestep: 171, Reward: 99.3078389977682
# NICE! Episode: 98, Timestep: 173, Reward: 99.84579429995551
# NICE! Episode: 98, Timestep: 174, Reward: 98.18334265093009
# NICE! Episode: 98, Timestep: 175, Reward: 99.29568714600127
# NICE! Episode: 98, Timestep: 176, Reward: 99.17914713179981
# NICE! Episode: 98, Timestep: 177, Reward: 98.64933742632641
# NICE! Episode: 98, Timestep: 178, Reward: 99.74001010539467
# NICE! Episode: 98, Timestep: 179, Reward: 98.64086368404162
# NICE! Episode: 98, Timestep: 180, Reward: 99.80094396297183
# NICE! Episode: 98, Timestep: 185, Reward: 98.103947583176
# NICE! Episode: 98, Timestep: 186, Reward: 99.39744531178496
# NICE! Episode: 98, Timestep: 188, Reward: 99.33660774171909
# NICE! Episode: 98, Timestep: 192, Reward: 98.66088863503066
# NICE! Episode: 98, Timestep: 193, Reward: 99.81977452349804
# NICE! Episode: 98, Timestep: 199, Reward: 99.08223782880306
# NICE! Episode: 98, Timestep: 200, Reward: 99.11246399373834
# NICE! Episode: 98, Timestep: 201, Reward: 99.36998406031535
# NICE! Episode: 98, Timestep: 208, Reward: 99.40337871615617
# NICE! Episode: 98, Timestep: 210, Reward: 99.68744168976097
# NICE! Episode: 98, Timestep: 211, Reward: 97.9174682334152
# NICE! Episode: 98, Timestep: 212, Reward: 99.51168948620274
# NICE! Episode: 98, Timestep: 213, Reward: 98.62963093176631
# NICE! Episode: 98, Timestep: 215, Reward: 98.52518415589091
# NICE! Episode: 98, Timestep: 218, Reward: 99.65218054821064
# NICE! Episode: 98, Timestep: 219, Reward: 99.86582745924177
# NICE! Episode: 98, Timestep: 223, Reward: 99.70257164229307
# NICE! Episode: 98, Timestep: 226, Reward: 99.4068626879253
# NICE! Episode: 98, Timestep: 229, Reward: 98.69361329112193
# NICE! Episode: 98, Timestep: 230, Reward: 98.68922120689699
# NICE! Episode: 98, Timestep: 231, Reward: 99.4826174251568
# NICE! Episode: 98, Timestep: 235, Reward: 99.77760728488043
# NICE! Episode: 98, Timestep: 237, Reward: 98.60355588313006
# NICE! Episode: 98, Timestep: 239, Reward: 99.44884241023793
# NICE! Episode: 98, Timestep: 240, Reward: 98.09540422271041
# NICE! Episode: 98, Timestep: 245, Reward: 99.29143664180337
# NICE! Episode: 98, Timestep: 246, Reward: 99.44999939095064
# NICE! Episode: 98, Timestep: 249, Reward: 99.36575585593347
# NICE! Episode: 98, Timestep: 252, Reward: 99.21133004949002
# NICE! Episode: 98, Timestep: 254, Reward: 98.32268847046481
# NICE! Episode: 98, Timestep: 255, Reward: 97.99250822520914
# NICE! Episode: 98, Timestep: 259, Reward: 99.81117269781512
# NICE! Episode: 98, Timestep: 262, Reward: 99.55507625831862
# NICE! Episode: 98, Timestep: 269, Reward: 98.28512237298317
# NICE! Episode: 98, Timestep: 270, Reward: 98.32286814512874
# NICE! Episode: 98, Timestep: 272, Reward: 98.88846471495485
# NICE! Episode: 98, Timestep: 273, Reward: 99.92943891039992
# NICE! Episode: 98, Timestep: 274, Reward: 98.26029029207162
# NICE! Episode: 98, Timestep: 275, Reward: 98.82971990028982
# NICE! Episode: 98, Timestep: 276, Reward: 99.30323903868063
# NICE! Episode: 98, Timestep: 278, Reward: 99.2973200782868
# NICE! Episode: 98, Timestep: 280, Reward: 98.0697625417929
# NICE! Episode: 98, Timestep: 284, Reward: 99.3870364738947
# NICE! Episode: 98, Timestep: 295, Reward: 99.24345914831176
# NICE! Episode: 98, Timestep: 304, Reward: 99.2296165850447
# NICE! Episode: 98, Timestep: 308, Reward: 99.87455394077107
# NICE! Episode: 98, Timestep: 309, Reward: 99.67072446546162
# NICE! Episode: 98, Timestep: 312, Reward: 99.86899369515305
# NICE! Episode: 98, Timestep: 313, Reward: 99.82128714023509
# NICE! Episode: 98, Timestep: 314, Reward: 99.25961360497384
# NICE! Episode: 98, Timestep: 316, Reward: 98.79808164517925
# NICE! Episode: 98, Timestep: 317, Reward: 98.13535508196773
# NICE! Episode: 98, Timestep: 321, Reward: 98.84955028920679
# NICE! Episode: 98, Timestep: 322, Reward: 99.46725027347179
# NICE! Episode: 98, Timestep: 323, Reward: 97.95327217236061
# NICE! Episode: 98, Timestep: 325, Reward: 99.59941561539321
# NICE! Episode: 98, Timestep: 328, Reward: 98.59736990002233
# NICE! Episode: 98, Timestep: 329, Reward: 99.86692060889088
# NICE! Episode: 98, Timestep: 330, Reward: 98.29198687714573
# NICE! Episode: 98, Timestep: 331, Reward: 98.70485284628793
# NICE! Episode: 98, Timestep: 335, Reward: 98.36497948994615
# NICE! Episode: 98, Timestep: 337, Reward: 98.44375058288858
# NICE! Episode: 98, Timestep: 341, Reward: 98.21622906545939
# NICE! Episode: 98, Timestep: 343, Reward: 98.28419070306796
# NICE! Episode: 98, Timestep: 344, Reward: 98.8187252869527
# NICE! Episode: 98, Timestep: 350, Reward: 99.15636067831254
# NICE! Episode: 98, Timestep: 358, Reward: 98.58108875326612
# NICE! Episode: 98, Timestep: 359, Reward: 99.00210973020319
# NICE! Episode: 98, Timestep: 360, Reward: 99.86727307710403
# NICE! Episode: 98, Timestep: 361, Reward: 99.61782607583865
# NICE! Episode: 98, Timestep: 364, Reward: 99.2982584794309
# NICE! Episode: 98, Timestep: 368, Reward: 98.29207533937365
# NICE! Episode: 98, Timestep: 375, Reward: 98.06710729484173
# NICE! Episode: 98, Timestep: 385, Reward: 99.23513343745547
# NICE! Episode: 98, Timestep: 388, Reward: 99.47615899268838
# NICE! Episode: 98, Timestep: 389, Reward: 98.67853008575719
# NICE! Episode: 98, Timestep: 390, Reward: 99.26208590419787
# NICE! Episode: 98, Timestep: 391, Reward: 98.34708925040762
# TEST
# -------------
# Runtime Duration:
# -------------
# -------------
# Avg PRBs used per user for SAC algorithm:
# -------------
# -------------
# Jain's fairness index for PRB allocation:
# -------------
# -------------
# Mean episodic rewards:
# -------------
# -------------
# Constraint Satisfaction:
# -------------
# -------------
# SSL Metrics:
# -------------
# -------------
# Comparison of Average E2E Delay (SAC):
# -------------
# -------------
# Average Data Rate (SAC):
# -------------
# -------------
# Average of total allocated power to each user (SAC):
# -------------
# -------------
# Sum of handovers :
# -------------
# Total time for 400 timesteps (8 users) in 100 Episdoes (aka iterations or epochs): 59.0 minutes 19.75618839263916 seconds

# %%
plot_graph("Mean episodic rewards",
           [moving_average(np.average(mat_reward, axis=0), window_size)],
           ['SAC'],
           ['blue'],
           ['solid'],
           "Episode",
           "Mean episodic rewards")
# Out:
# -------------
# Mean episodic rewards:
# -------------

# %%
start=80
end=90
plot_graph("SSL Metrics",
           [moving_average(np.average(mat_ssl_rate[:,start:end], axis=1), window_size),
            moving_average(np.average(mat_ssl_delay[:,start:end], axis=1), window_size),
            moving_average(np.average(mat_ssl[:,start:end], axis=1), window_size)],
           ['Rate (SAC)',
            'Delay (SAC)',
            'SSL (SAC)'],
           ['blue', 'green', 'orange'],
           ['solid', 'solid', 'solid'],
           "Episode",
           "SSL Metrics")

# %%
#%% %PLOTTING THE RESULTS%%
window_size = 400  # (for smoothing the curves in the plots)
#####
LC.visualize_ru_du_locations(du_ru_adj_matrix)
# %%%%RUNTIME DURATION%%%%%%%
# Calculate the average episode runtime and its moving average
# mean_mat_episode_runtime = moving_average(1000*np.average(mat_episode_runtime, axis=1), window_size) 

# Plot the data using your custom plot function
plot_graph("Runtime Duration",
           [moving_average(1000*np.average(mat_episode_runtime, axis=1), window_size)],
           ['Average runtime duration: {:.2f} ms'.format(1000 * np.average(mat_episode_runtime))],
           ['blue'],
           ['solid'],
           "Episode",
           "Runtime duration (ms)")
#PRB Allocation?
# Calculate the average number of PRBs used per BS for SAC and SAC_pred
# avg_prbs_sac = mat_used_prbs_per_user_per_bs.mean(axis=(0,2,3))
# # avg_prbs_sac_pred = mat_used_prbs_per_user_per_bs_pred.mean(axis=(0,2,3))

# # Create an array with the positions of each bar on the x-axis
# barWidth = 0.3
# r1 = np.arange(len(avg_prbs_sac))
# r2 = [x + barWidth for x in r1]

# # Create the bar chart
# plt.bar(r1, avg_prbs_sac, color='b', width=barWidth, edgecolor='grey', label='SAC')
# # plt.bar(r2, avg_prbs_sac_pred, color='r', width=barWidth, edgecolor='grey', label='SAC_pred')

# # Add xticks on the middle of the group bars
# plt.xlabel('BS', fontweight='bold')
# plt.xticks([r + barWidth/2 for r in range(BS_NO)], range(1, BS_NO+1))

# plt.ylabel('Average number of PRBs used')
# plt.legend()

# # Show the plot
# plt.show()

########################
# Select data for BS=0
# prbs_per_user_per_bs_0 = mat_used_prbs_per_user_per_bs[:, 0, :, :]
# # prbs_per_user_per_bs_pred_0 = mat_used_prbs_per_user_per_bs_pred[:, 4, :, :]

# # Sum over users and then calculate averages over Monte Carlo runs
# sum_prbs_per_user_per_bs_0 = np.sum(prbs_per_user_per_bs_0, axis=1)
# # sum_prbs_per_user_per_bs_pred_0 = np.sum(prbs_per_user_per_bs_pred_0, axis=1)

# avg_prbs_per_user_per_bs_0 = np.mean(sum_prbs_per_user_per_bs_0, axis=0)
# # avg_prbs_per_user_per_bs_pred_0 = np.mean(sum_prbs_per_user_per_bs_pred_0, axis=0)

# # Plot the averages using your function
# plot_graph('Overall PRBs used for BS=4 for SAC algorithm',
#            [avg_prbs_per_user_per_bs_0],
#            ['SAC'],
#            ['b'],
#            ['-'],
#            'T',
#            'Overall PRBs used in BS 4')
# plot_graph('Overall PRBs used for BS=4 for SAC and SAC_pred algorithms',
#            [avg_prbs_per_user_per_bs_0, avg_prbs_per_user_per_bs_pred_0],
#            ['SAC', 'SAC_pred'],
#            ['b', 'r'],
#            ['-', '--'],
#            'T',
#            'Overall PRBs used in BS 4')
#######################
# Calculate averages over Monte Carlo runs and users
avg_prbs_per_user = np.mean(mat_used_prbs_per_user, axis=(1,2))
# avg_prbs_per_user = np.mean(mat_used_prbs_per_user, axis=(0,1))
# avg_prbs_per_user_pred = np.mean(mat_used_prbs_per_user_pred, axis=(0,1))

# Plot the averages using your function
plot_graph('Avg PRBs used per user for SAC algorithm',
           [moving_average(avg_prbs_per_user , window_size)],
           ['SAC'],
           ['b'],
           ['-'],
           'T',
           'Average PRBs used per user')
# plot_graph('Avg PRBs used per user for SAC and SAC_pred algorithms',
#            [avg_prbs_per_user, avg_prbs_per_user_pred],
#            ['SAC', 'SAC_pred'],
#            ['b', 'r'],
#            ['-', '--'],
#            'T',
#            'Average PRBs used per user')
# Fairness for PRBs
# Calculate PRB utilization for each user at each time step and for each MC run
prb_utilization = np.sum(mat_rho, axis=(2, 1))  # Sum over PRBs and BSs

# Calculate proportional fairness score for each time step
fairness_scores = np.zeros((E, T))

for e in range(E):
    for t in range(T):
        # Calculate Jain's fairness index for time step t in MC run mc
        sum_of_prbs = np.sum(prb_utilization[e, :, t])
        sum_of_squares = np.sum(prb_utilization[e, :, t] ** 2)
        # Handle potential division by zero or NaN
        if sum_of_prbs == 0 or np.isnan(sum_of_squares):
            fairness_scores[e, t] = 0  # Set fairness score to 0
        else:
            fairness_scores[e, t] = (sum_of_prbs ** 2) / (BS_NO * sum_of_squares)

# Average fairness scores over all MC runs
# avg_fairness_scores = np.mean(fairness_scores, axis=0)
avg_fairness_scores = np.mean(fairness_scores, axis=1)
normalized_fairness_scores = (avg_fairness_scores - np.min(avg_fairness_scores)) / (np.max(avg_fairness_scores) - np.min(avg_fairness_scores))


plot_graph("Jain's fairness index for PRB allocation",
           [moving_average(normalized_fairness_scores , window_size)],
           ['SAC'],
           ['blue'],
           ['solid'],
           "Episode",
           "Mean fairness score")

# %%REWARD%%%%
#mat_reward_average_over_m = np.average(mat_reward, axis=1) #axis=0
# mat_reward_average_over_m_pred = np.average(mat_reward_pred, axis=0)

# mean_ep_rewardall = moving_average(mat_reward_average_over_m, window_size)
# mean_ep_rewardall_pred = moving_average(mat_reward_average_over_m_pred, window_size)
plot_graph("Mean episodic rewards",
           [moving_average(np.average(mat_reward, axis=1), window_size)],
           ['SAC'],
           ['blue'],
           ['solid'],
           "Episode",
           "Mean episodic rewards")
# plot_graph("Mean episodic rewards",
#            [mean_ep_rewardall, mean_ep_rewardall_pred],
#            ['SAC', 'Proactive SAC'],
#            ['blue', 'green'],
#            ['solid', 'dotted'],
#            "Episode",
#            "Mean episodic rewards")
# %%CONSTRAINT SATISFACTION%
# mean_ep_prb_const = moving_average(np.average(mat_satisfied_prb_constraint, axis=1), window_size)
# # mean_ep_prb_const_pred = moving_average(np.average(mat_satisfied_prb_constraint_pred, axis=0), window_size)
# mean_ep_power_const = moving_average(np.average(mat_satisfied_power_constraint, axis=1), window_size)
# # mean_ep_power_const_pred = moving_average(np.average(mat_satisfied_power_constraint_pred, axis=0), window_size)
# mean_ep_delay_const = moving_average(np.average(mat_satisfied_delay_constraint, axis=1), window_size)
# # mean_ep_delay_const_pred = moving_average(np.average(mat_satisfied_delay_constraint_pred, axis=0), window_size)
# mean_ep_rate_const = moving_average(np.average(mat_satisfied_rate_constraint, axis=1), window_size)

plot_graph("Constraint Satisfaction",
           [moving_average(np.average(mat_satisfied_prb_constraint, axis=1), window_size), 
            moving_average(np.average(mat_satisfied_power_constraint, axis=1), window_size),
            moving_average(np.average(mat_satisfied_delay_constraint, axis=1), window_size),
            moving_average(np.average(mat_satisfied_rate_constraint, axis=1), window_size)],
           ['PRB (SAC)',
            'Power (SAC)',
            'Delay (SAC)',
            'Rate (SAC)'],
           ['red', 'blue', 'green', 'orange'],
           ['solid', 'solid', 'solid', 'solid'],
           "Episode",
           "Constraint Satisfaction Rate")

# plot_graph("Constraint Satisfaction",
#            [mean_ep_prb_const, mean_ep_prb_const_pred,
#             mean_ep_power_const, mean_ep_power_const_pred,
#             mean_ep_delay_const, mean_ep_delay_const_pred],
#            ['PRB (SAC)', 'PRB (SAC_pred)',
#             'Power (SAC)', 'Power (SAC_pred)',
#             'Delay (SAC)', 'Delay (SAC_pred)'],
#            ['red', 'red', 'blue', 'blue', 'green', 'green'],
#            ['solid', 'dotted', 'solid', 'dotted', 'solid', 'dotted'],
#            "Episode",
#            "Constraint Satisfaction")
# %%%%%SSL%%%%%%
# mean_ep_ssl_rate = moving_average(np.average(mat_ssl_rate, axis=1), window_size)
# mean_ep_ssl_delay = moving_average(np.average(mat_ssl_delay, axis=1), window_size)
# mean_ep_ssl = moving_average(np.average(mat_ssl, axis=1), window_size)
# mean_ep_ssl_rate_pred = moving_average(np.average(mat_ssl_rate_pred, axis=0), window_size)
# mean_ep_ssl_delay_pred = moving_average(np.average(mat_ssl_delay_pred, axis=0), window_size)
# mean_ep_ssl_pred = moving_average(np.average(mat_ssl_pred, axis=0), window_size)

# plot_graph("SSL Metrics",
#            [mean_ep_ssl_rate, mean_ep_ssl_rate_pred,
#             mean_ep_ssl_delay, mean_ep_ssl_delay_pred,
#             mean_ep_ssl, mean_ep_ssl_pred],
#            ['Rate (SAC)', 'Rate (SAC_pred)',
#             'Delay (SAC)', 'Delay (SAC_pred)',
#             'SSL (SAC)', 'SSL (SAC_pred)'],
#            ['blue', 'blue', 'green', 'green', 'orange', 'orange'],
#            ['solid', 'dotted', 'solid', 'dotted', 'solid', 'dotted'],
#            "Episode",
#            "SSL Metrics")
plot_graph("SSL Metrics",
           [moving_average(np.average(mat_ssl_rate, axis=1), window_size),
            moving_average(np.average(mat_ssl_delay, axis=1), window_size),
            moving_average(np.average(mat_ssl, axis=1), window_size)],
           ['Rate (SAC)',
            'Delay (SAC)',
            'SSL (SAC)'],
           ['blue', 'green', 'orange'],
           ['solid', 'solid', 'solid'],
           "Episode",
           "SSL Metrics")
# %%%%%Delay%%%%%%
# Calculate mean delay over users for SAC
mean_delay_sac = np.mean(np.mean(monte_mat_delay_tot, axis=1), axis=1)
#mean_delay_sac = np.mean(np.mean(monte_mat_delay_tot, axis=1), axis=0)
# Calculate mean delay over users for SAC_pred
# mean_delay_sac_pred = np.mean(np.mean(monte_mat_delay_tot_pred, axis=1), axis=0)

# Apply moving average to smooth the curves
# mean_delay_sac_smoothed = moving_average(mean_delay_sac, window_size)
# mean_delay_sac_pred_smoothed = moving_average(mean_delay_sac_pred, window_size)

# Plot the comparison graph
plot_graph("Comparison of Average E2E Delay (SAC)",
           [moving_average(mean_delay_sac , window_size)],
           ['SAC'],
           ['blue'],
           ['solid'],
           "Timestep",
           "Average E2E Delay (ms)")
# plot_graph("Comparison of Average E2E Delay (SAC vs. SAC_pred)",
#            [mean_delay_sac_smoothed, mean_delay_sac_pred_smoothed],
#            ['SAC', 'SAC_pred'],
#            ['blue', 'green'],
#            ['solid', 'solid'],
#            "Timestep",
#            "Average E2E Delay (ms)")
#####################
# mean_rate_sac = np.mean(np.mean(shannon, axis=1), axis=0)
mean_rate_sac = np.mean(np.mean(shannon, axis=1), axis=1)
# mean_rate_sac_smoothed = moving_average(mean_rate_sac, window_size)
plot_graph("Average Data Rate (SAC)",
           [moving_average(mean_rate_sac , window_size)],
           ['SAC'],
           ['blue'],
           ['solid'],
           "Timestep",
           "Average Data Rate (Mbps)")

#####################
mean_power_sac = np.mean(np.mean(mat_power, axis=1), axis=1)
# mean_power_sac_smoothed = moving_average(mean_power_sac, window_size)
plot_graph("Average of total allocated power to each user (SAC)",
           [moving_average(mean_power_sac , window_size)],
           ['SAC'],
           ['blue'],
           ['solid'],
           "Timestep",
           "Average of total allocated power to each user (W)")

###
average_rate = np.mean(shannon, axis=2)

for user_idx in range(USER_NO):
    plt.plot(moving_average(range(E), window_size), moving_average(average_rate[:,user_idx], window_size), label=f'User {user_idx+1}')
plt.xlabel('E')
plt.ylabel('Rate (Mbps)')
plt.title('Average rate for individual users')
plt.legend()
plt.show()

###
average_rate_ssl_u = np.mean(mat_fittingness_u_rate, axis=2)

for user_idx in range(USER_NO):
    plt.plot(moving_average(range(E), window_size), moving_average(average_rate_ssl_u[:,user_idx], window_size), label=f'User {user_idx+1}')
plt.xlabel('E')
plt.ylabel('SSL_rate_u')
plt.title('Normalized rate satisfaction')
plt.legend()
plt.show()

###
average_delay_ssl_u = np.mean(mat_fittingness_u_delay, axis=2)

for user_idx in range(USER_NO):
    plt.plot(moving_average(range(E), window_size), moving_average(average_delay_ssl_u[:,user_idx], window_size), label=f'User {user_idx+1}')
plt.xlabel('E')
plt.ylabel('SSL_delay_u')
plt.title('Normalized delay satisfaction')
plt.legend()
plt.show()
###
plot_graph("Sum of handovers ",
           [moving_average(np.sum(mat_count_handovers, axis=1) , window_size)],
           ['SAC'],
           ['blue'],
           ['solid'],
           "Episode",
           "Sum of handovers")

###
# plot_graph("Average No. of handovers per user",
#            [moving_average(np.average(mat_count_handovers, axis=1) , window_size)],
#            ['SAC'],
#            ['blue'],
#            ['solid'],
#            "Timestep",
#            "Average No. of handovers per user")
# ###

# for user_idx in range(USER_NO):
#     plt.plot(moving_average(range(E), window_size), moving_average(mat_count_handovers[:,user_idx], window_size), label=f'User {user_idx+1}')
# plt.xlabel('E')
# plt.ylabel('No. of handovers per user')
# plt.title('No. of handovers per user')
# plt.legend()
# plt.show()


print(style.UNDERLINE + "Total time for {} timesteps ({} users) in {} Episdoes (aka iterations or epochs): {}".format(T, USER_NO, E, convert_seconds(np.sum(mat_episode_runtime))))

# %%
ef __init__(self, alpha, beta, n_actions, input_dims, tau = 0.005,
            layer1_size = 500, layer2_size = 256, batch_size = 64, reward_scale = 0.2): #input_dims (state size)
        self.gamma = 0.9


# config.yaml lstm
# config.yaml lstm
# config.yaml 
USER_NO: 8 #10 #20 # 4
BW: 180000  # %  180 kHz  (to be updated after consulting with Faouzi)
PRB_NO: 200 #  (to be updated after consulting with Faouzi)
SIGMA_NOISE: 10**(-17.4) #3.981e-18 # # = -174 dBm <tnsm23nouruzi> #
ETA_AREA: 3 # for rural areas according to TS 38.215 (Used in the Rayleigh/Distance formula for calculating data rate (Shannon)); equal to 3 for rural; 4 for urban areas # check also 38.913 for mobility scenarios and classes
X_LIM: 1000
Y_LIM: 1000
#CU_NO: 1 # only 1 CU is envisioned. It is co-located with the Near-RT RIC
DU_NO: 2 # all connected to the CU
RU_PER_DU_NO: 2 # Each DU has 4 RUs; Total number of RUs = 4*2 = 8
#BS_NO: 20 # should be equal to RU_PER_DU_NO*DU_NO # static for now; Location.bs_location() --- now it is bound to 4 BSs. Can be changed later
FH_BW_CAPACITY: 5000 # 100 Mbps in twc23kavehmadani# Mbps (5 Gbps) (link between RU and its DU) #
E2_BW_CAPACITY: 100000 # 5 Gbps in twc23kavehmadani #Mbps (100 Gbps) (link between DU and Near-RT RIC (equal to F1, which is between DU and CU))
#VM_NO: 9 # 6
#VNF_NO: 5 # 5
#NODE_NO: 12
SLICE_NO: 3 #5 # number of slice types ; will be indexed from 0 to (SLICE_NO - 1)
MAX_POWER: 40 # in watts ; equals to 46 dBm <tvt23choi> # 12 # (to be updated after consulting with Faouzi) # 46 dBm in tvt23choi = 40 watts (Much higher than normal papers)
OMEGA_1: 0.5 # to use in SSL weighting (for data rate term)
VELOCITY: 0 #0 #-1 means random #35 # m/s [5,20,35,50] #             = self.V ##################################################
CONST_D_MAX: 20 # 20 #-1 # ms
CONST_R_MIN: 10 # 5 #-1 # Mbps  
#ISOLATION_ORDER: -1
PACKET_SIZE: 0.012 # 0.012 # based on 1500 bytes for eMBB # in mbits # -1 # twc23kavehmadani: 1 KB for URLLC and 125 KB for eMBB
#PACKET_NO: 830  # 500 # -1 # packet generation rate per second # 0.012*500 = 6 Mbps # 0.012*830 = 9.96 Mbps
RAYLEIGH_SCALE: 1 # sigma in Rayleigh formula
#Episodes (T) and Number of monte-carlo runs:#
E: 10000 #1000# episodes/epochs for learning (the loop before T loop (replaces MC loop))
T: 20 #100# 14000 # 1000  # Number of timeslots
#MC: 3  # Number of Monte-carlo runs
#Hyperparameters for the DRL algorithm
ALPHA_ACT: 0.01 #01 # 0.00001 # 0.00001 #0.000001 # actor's learning rate
BETA_ACT: 0.01 # 0.00005 # 0.00005 # 0.00005 # 0.000005 # Critic's learning rate
VAR: 1
DECAY_VAR: 0.99 #95 #95 # .995 # can determine the ratio of exploration to exploitation
PSI: 0.25 # for putting two last actions in states
