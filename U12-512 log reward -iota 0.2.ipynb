# %%
# %run "main_constraint-based.py"
# Out:
# 20 3000
# /share/home2/ebrahimis/project1_3_8/venv/lib/python3.8/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:397: RuntimeWarning: divide by zero encountered in log10
#   self.signal_strength_dB[u] = 10 * np.log10(self.signal_strength)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:401: RuntimeWarning: divide by zero encountered in log10
#   self.SINR_dB[u] = 10 * np.log10(self.SINR)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:395: RuntimeWarning: divide by zero encountered in log10
#   self.interference_dB[u] = 10 * np.log10(I_inter)
# NICE! Episode: 0, Timestep: 79, Reward: -0.07099687987303782
# NICE! Episode: 0, Timestep: 312, Reward: -0.06207593070324518
# NICE! Episode: 0, Timestep: 314, Reward: -0.05419957104865923
# NICE! Episode: 0, Timestep: 907, Reward: -0.06020299745922718
# NICE! Episode: 0, Timestep: 908, Reward: -0.05507482147426339
# NICE! Episode: 0, Timestep: 1218, Reward: -0.0789219967071116
# NICE! Episode: 0, Timestep: 1220, Reward: -0.05591956220993662
# NICE! Episode: 0, Timestep: 1274, Reward: -0.029332176993002005
# NICE! Episode: 0, Timestep: 1275, Reward: -0.021346377060026067
# NICE! Episode: 0, Timestep: 1276, Reward: -0.018828502064849657
# NICE! Episode: 0, Timestep: 1277, Reward: -0.018259414473438863
# NICE! Episode: 0, Timestep: 1278, Reward: -0.031998432895155776
# NICE! Episode: 0, Timestep: 1282, Reward: -0.01276599075651922
# NICE! Episode: 0, Timestep: 1283, Reward: -0.01946853593761967
# NICE! Episode: 0, Timestep: 1284, Reward: -0.010710203199468865
# NICE! Episode: 0, Timestep: 1285, Reward: -0.015395464620279449
# NICE! Episode: 0, Timestep: 1286, Reward: -0.016075299383711102
# NICE! Episode: 0, Timestep: 1290, Reward: -0.043253331604869334
# NICE! Episode: 0, Timestep: 1292, Reward: -0.04177915762822675
# NICE! Episode: 0, Timestep: 1719, Reward: -0.04672685389875493
# NICE! Episode: 0, Timestep: 2780, Reward: -0.04248632530463447
# NICE! Episode: 0, Timestep: 2840, Reward: -0.046465100016891164
# NICE! Episode: 0, Timestep: 2842, Reward: -0.041664466588561135
# Total Handovers  over all timesteps: Episode 0= 1335 HOs, reward= -0.6207609083866725
# NICE! Episode: 1, Timestep: 17, Reward: -0.027954322472598252
# NICE! Episode: 1, Timestep: 18, Reward: -0.02232415870253266
# NICE! Episode: 1, Timestep: 21, Reward: -0.031222038535937732
# NICE! Episode: 1, Timestep: 96, Reward: -0.10281419270752902
# NICE! Episode: 1, Timestep: 109, Reward: -0.0617626785882832
# NICE! Episode: 1, Timestep: 115, Reward: -0.05710775002792246
# NICE! Episode: 1, Timestep: 118, Reward: -0.04838584589647433
# NICE! Episode: 1, Timestep: 1013, Reward: -0.01579655578829152
# NICE! Episode: 1, Timestep: 1016, Reward: -0.02740652722681361
# NICE! Episode: 1, Timestep: 1017, Reward: -0.03189130952398607
# NICE! Episode: 1, Timestep: 1018, Reward: -0.00857323666544092
# NICE! Episode: 1, Timestep: 1019, Reward: -0.013901132083916747
# NICE! Episode: 1, Timestep: 1024, Reward: -0.033522505704066244
# NICE! Episode: 1, Timestep: 1025, Reward: -0.01533052522374296
# NICE! Episode: 1, Timestep: 1029, Reward: -0.013986051748141489
# NICE! Episode: 1, Timestep: 1133, Reward: -0.05566667686316174
# NICE! Episode: 1, Timestep: 1243, Reward: -0.01913687414971114
# NICE! Episode: 1, Timestep: 1246, Reward: -0.04190640045078159
# NICE! Episode: 1, Timestep: 1253, Reward: -0.026210238641313152
# NICE! Episode: 1, Timestep: 1255, Reward: -0.012445783386261438
# NICE! Episode: 1, Timestep: 1256, Reward: -0.01007835751156816
# NICE! Episode: 1, Timestep: 1263, Reward: -0.04931103163547658
# NICE! Episode: 1, Timestep: 1286, Reward: -0.03877622596557322
# NICE! Episode: 1, Timestep: 1288, Reward: -0.03290278077495895
# NICE! Episode: 1, Timestep: 1290, Reward: -0.012926348170916625
# NICE! Episode: 1, Timestep: 1307, Reward: -0.03155227200077848
# NICE! Episode: 1, Timestep: 1308, Reward: -0.024279150351156735
# NICE! Episode: 1, Timestep: 1331, Reward: -0.04023645095215092
# NICE! Episode: 1, Timestep: 1469, Reward: -0.04024094596408277
# NICE! Episode: 1, Timestep: 2004, Reward: -0.05605217303387667
# NICE! Episode: 1, Timestep: 2068, Reward: -0.04580233160372467
# NICE! Episode: 1, Timestep: 2931, Reward: -0.04447481889845582
# NICE! Episode: 1, Timestep: 2932, Reward: -0.023183228132731555

# %%
plot_graph("Mean episodic rewards",
           [moving_average(np.average(mat_reward, axis=1), 1)],
           ['SAC'],
           ['blue'],
           ['solid'],
           "Episode",
           "Mean episodic rewards")

# %%
import numpy as np
plot_graph("SSL Metrics",
           [np.mean(mat_ssl_rate, axis=0),
            np.mean(mat_ssl_delay, axis=0),
            np.average(mat_ssl, axis=0)],
           ['Rate (SAC)',
            'Delay (SAC)',
            'SSL (SAC)'],
           ['blue', 'green', 'orange'],
           ['solid', 'solid', 'solid'],
           "Episode",
           "SSL Metrics")

# %%
import numpy as np
i=200
plot_graph("SSL Metrics",
           [mat_ssl_rate[i,:],mat_ssl_delay[i,:],mat_ssl[i,:]],
           ['Rate (SAC)',
            'Delay (SAC)',
            'SSL (SAC)'],
           ['blue', 'green', 'orange'],
           ['solid', 'solid', 'solid'],
           "Episode",
           "SSL Metrics")

# %%
512*512 networks
self.reparam_noise = 1e-8 #1e-6 
 

    def __init__(self, alpha, beta, n_actions, input_dims, tau = 0.001,
            layer1_size = 500, layer2_size = 256, batch_size = 32, reward_scale = 1): #input_dims (state size)
        self.gamma = 0.99
 # config.yaml lstm
# config.yaml lstm
# config.yaml 
USER_NO: 12 #10 #20 # 4
BW: 180000  # %  180 kHz  (to be updated after consulting with Faouzi)
PRB_NO: 100 #  (to be updated after consulting with Faouzi)
SIGMA_NOISE: 10**(-17.4) #3.981e-18 # # = -174 dBm <tnsm23nouruzi> #
ETA_AREA: 3 # for rural areas according to TS 38.215 (Used in the Rayleigh/Distance formula for calculating data rate (Shannon)); equal to 3 for rural; 4 for urban areas # check also 38.913 for mobility scenarios and classes
X_LIM: 1000
Y_LIM: 1000
#CU_NO: 1 # only 1 CU is envisioned. It is co-located with the Near-RT RIC
DU_NO: 2 # all connected to the CU
RU_PER_DU_NO: 3 # Each DU has 4 RUs; Total number of RUs = 4*2 = 8
#BS_NO: 20 # should be equal to RU_PER_DU_NO*DU_NO # static for now; Location.bs_location() --- now it is bound to 4 BSs. Can be changed later
FH_BW_CAPACITY: 5000 # 100 Mbps in twc23kavehmadani# Mbps (5 Gbps) (link between RU and its DU) #
E2_BW_CAPACITY: 100000 # 5 Gbps in twc23kavehmadani #Mbps (100 Gbps) (link between DU and Near-RT RIC (equal to F1, which is between DU and CU))
#VM_NO: 9 # 6
#VNF_NO: 5 # 5
#NODE_NO: 12
SLICE_NO: 3 #5 # number of slice types ; will be indexed from 0 to (SLICE_NO - 1)
MAX_POWER: 40 # in watts ; equals to 46 dBm <tvt23choi> # 12 # (to be updated after consulting with Faouzi) # 46 dBm in tvt23choi = 40 watts (Much higher than normal papers)
OMEGA_1: 0.3 # to use in SSL weighting (for data rate term)
VELOCITY: 10 #0 #-1 means random #35 # m/s [5,20,35,50] #             = self.V ##################################################
CONST_D_MAX: -1 # 20 #-1 # ms
CONST_R_MIN: -1 # 5 #-1 # Mbps  
#ISOLATION_ORDER: -1
PACKET_SIZE: -1 # 0.012 # based on 1500 bytes for eMBB # in mbits # -1 # twc23kavehmadani: 1 KB for URLLC and 125 KB for eMBB
#PACKET_NO: 830  # 500 # -1 # packet generation rate per second # 0.012*500 = 6 Mbps # 0.012*830 = 9.96 Mbps
RAYLEIGH_SCALE: 1 # sigma in Rayleigh formula
#Episodes (T) and Number of monte-carlo runs:#
E: 20 #1000# episodes/epochs for learning (the loop before T loop (replaces MC loop))
T: 3000 #100# 14000 # 1000  # Number of timeslots
#MC: 3  # Number of Monte-carlo runs
#Hyperparameters for the DRL algorithm
ALPHA_ACT: 0.00001 #01 # 0.00001 # 0.00001 #0.000001 # actor's learning rate
BETA_ACT: 0.00005 # 0.00005 # 0.00005 # 0.00005 # 0.000005 # Critic's learning rate
VAR: 1
DECAY_VAR: 0.999 #95 #95 # .995 # can determine the ratio of exploration to exploitation
PSI: 0.5 # for putting two last actions in states
XI: 5 # shaping parameter for SSL^B_u and SSL^D_u
IOTA: 0.2 # regularization parameter that controls the penalty for low satisfaction levels

# %%
plot_graph("SSL Metrics",
           [np.average(mat_ssl_rate, axis=0),
            np.average(mat_ssl_delay, axis=0),
            np.average(mat_ssl, axis=0)],
           ['Rate (SAC)',
            'Delay (SAC)',
            'SSL (SAC)'],
           ['blue', 'green', 'orange'],
           ['solid', 'solid', 'solid'],
           "Episode",
           "SSL Metrics")
