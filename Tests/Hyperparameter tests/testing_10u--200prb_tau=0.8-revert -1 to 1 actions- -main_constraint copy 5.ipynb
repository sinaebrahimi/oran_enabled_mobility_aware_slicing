# %%
# %run "main_constraint-based.py"
# Out:
# 0
# /share/home2/ebrahimis/project1_3_8/venv/lib/python3.8/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:393: RuntimeWarning: divide by zero encountered in log10
#   self.signal_strength_dB[u] = 10 * np.log10(self.signal_strength)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:397: RuntimeWarning: divide by zero encountered in log10
#   self.SINR_dB[u] = 10 * np.log10(self.SINR)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:391: RuntimeWarning: divide by zero encountered in log10
#   self.interference_dB[u] = 10 * np.log10(I_inter)
# 1000
# 2000
# 3000
# Total Handovers  over all timesteps: MC 0= 0 HOs
# 0
# 1000
# 2000
# 3000
# ...

# %% [markdown]
# T: 4000 # 14000 # 1000  # Number of timeslots
# MC: 4  # Number of Monte-carlo runs
# #Hyperparameters for the DRL algorithm
# ALPHA_ACT: 0.0001 # 0.00001 # 0.00001 #0.000001
# BETA_ACT: 0.0001 # 0.00005 # 0.00005 # 0.000005
# VAR: 1
# DECAY_VAR: 0.99
#
# def __init__(self, alpha, beta, n_actions, input_dims, tau = 0.005,
#             layer1_size = 500, layer2_size = 256, batch_size = 256, reward_scale = 1): #input_dims (state size)
#         self.gamma = 0.8 # 0.5 to 0.8###if it is near 1, it'd be very dependent to the past; therefore, not very adaptable to changes #0.8 ####CHANGE TO 0.8 # 0.99 #0.8 in the TNSM22 paper # was 0.7 in orig code
#         self.tau = tau # tau # 0.001 in the paper #was 0.5 in orig code
#         self.pointer = 0
#         self.max_size = 60000
