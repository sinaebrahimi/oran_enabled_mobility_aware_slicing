# %%
# %run "main_constraint-based.py"
# Out:
# 4 5000
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/0new_mdp_design/radio_calc.py:555: RuntimeWarning: divide by zero encountered in log10
#   self.signal_strength_dB[u] = 10 * np.log10(self.signal_strength)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/0new_mdp_design/radio_calc.py:559: RuntimeWarning: divide by zero encountered in log10
#   self.SINR_dB[u] = 10 * np.log10(self.SINR)
# reward:  0.8016700532746615
# -------------
# Reward (Until timestep 0/5000 of run 0/4):
# -------------
# /share/home2/ebrahimis/project1_3_8/venv/lib/python3.8/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/0new_mdp_design/radio_calc.py:553: RuntimeWarning: divide by zero encountered in log10
#   self.interference_dB[u] = 10 * np.log10(I_inter)
# reward:  0.9489410812243267
# -------------
# Reward (Until timestep 300/5000 of run 0/4):
# -------------
# reward:  0.6694597151762957
# -------------
# Reward (Until timestep 600/5000 of run 0/4):
# -------------
# reward:  0.8520395197735634
# -------------
# Reward (Until timestep 900/5000 of run 0/4):
# -------------
# reward:  0.8244604547587728
# -------------
# Reward (Until timestep 1200/5000 of run 0/4):
# -------------
# reward:  0.6698200654090928
# -------------
# Reward (Until timestep 1500/5000 of run 0/4):
# -------------
# reward:  0.9199407897919518
# -------------
# Reward (Until timestep 1800/5000 of run 0/4):
# -------------
# reward:  0.8405838492165685
# -------------
# Reward (Until timestep 2100/5000 of run 0/4):
# -------------
# reward:  0.8926105906640109
# -------------
# Reward (Until timestep 2400/5000 of run 0/4):
# -------------
# reward:  0.9640791807849713
# -------------
# Reward (Until timestep 2700/5000 of run 0/4):
# -------------
# reward:  0.8947075151248164
# -------------
# Reward (Until timestep 3000/5000 of run 0/4):
# -------------
# reward:  0.8833637992811867
# -------------
# Reward (Until timestep 3300/5000 of run 0/4):
# -------------
# reward:  0.707133568426101
# -------------
# Reward (Until timestep 3600/5000 of run 0/4):
# -------------
# reward:  0.8622918022064101
# -------------
# Reward (Until timestep 3900/5000 of run 0/4):
# -------------
# reward:  0.8593660806035249
# -------------
# Reward (Until timestep 4200/5000 of run 0/4):
# -------------
# reward:  0.8887333381324491
# -------------
# Reward (Until timestep 4500/5000 of run 0/4):
# -------------
# reward:  0.9276510953708995
# -------------
# Reward (Until timestep 4800/5000 of run 0/4):
# -------------
# Total Handovers  over all timesteps: Episode 0= 5466 HOs, reward= 0.8322167957998362
# reward:  0.8907011658007479
# -------------
# Reward (Until timestep 0/5000 of run 1/4):
# -------------
# reward:  0.2803698548680464
# -------------
# Reward (Until timestep 300/5000 of run 1/4):
# -------------
# reward:  0.3805844576231871
# -------------
# Reward (Until timestep 600/5000 of run 1/4):
# -------------
# reward:  0.8807961394571081
# -------------
# Reward (Until timestep 900/5000 of run 1/4):
# -------------
# reward:  0.8978115313917988
# -------------
# Reward (Until timestep 1200/5000 of run 1/4):
# -------------
# reward:  0.8467958068686271
# -------------
# Reward (Until timestep 1500/5000 of run 1/4):
# -------------
# reward:  0.7992480587691038
# -------------
# Reward (Until timestep 1800/5000 of run 1/4):
# -------------
# reward:  0.8538845797387588
# -------------
# Reward (Until timestep 2100/5000 of run 1/4):
# -------------
# reward:  0.8421486907734237
# -------------
# Reward (Until timestep 2400/5000 of run 1/4):
# -------------
# reward:  0.8829987073697041
# -------------
# Reward (Until timestep 2700/5000 of run 1/4):
# -------------
# reward:  0.9070605341053595
# -------------
# Reward (Until timestep 3000/5000 of run 1/4):
# -------------
# reward:  0.9458736024345873
# -------------
# Reward (Until timestep 3300/5000 of run 1/4):
# -------------
# reward:  0.8917654520358395
# -------------
# Reward (Until timestep 3600/5000 of run 1/4):
# -------------
# reward:  0.7978069080079526
# -------------
# Reward (Until timestep 3900/5000 of run 1/4):
# -------------
# reward:  0.793090300029061
# -------------
# Reward (Until timestep 4200/5000 of run 1/4):
# -------------
# reward:  0.7836762700606105
# -------------
# Reward (Until timestep 4500/5000 of run 1/4):
# -------------
# reward:  0.8544542741902978
# -------------
# Reward (Until timestep 4800/5000 of run 1/4):
# -------------
# Total Handovers  over all timesteps: Episode 1= 5067 HOs, reward= 0.9120555234515298
# reward:  0.8259657859238573
# -------------
# Reward (Until timestep 0/5000 of run 2/4):
# -------------
# reward:  0.3226546230987566
# -------------
# Reward (Until timestep 300/5000 of run 2/4):
# -------------
# reward:  0.8983161676891064
# -------------
# Reward (Until timestep 600/5000 of run 2/4):
# -------------
# reward:  0.9179606269210671
# -------------
# Reward (Until timestep 900/5000 of run 2/4):
# -------------
# reward:  0.8936302138403542
# -------------
# Reward (Until timestep 1200/5000 of run 2/4):
# -------------
# reward:  0.6995136290148788
# -------------
# Reward (Until timestep 1500/5000 of run 2/4):
# -------------
# reward:  0.8329849774575002
# -------------
# Reward (Until timestep 1800/5000 of run 2/4):
# -------------
# reward:  0.8583247581181703
# -------------
# Reward (Until timestep 2100/5000 of run 2/4):
# -------------
# reward:  0.8367830342209026
# -------------
# Reward (Until timestep 2400/5000 of run 2/4):
# -------------
# reward:  0.8014343521418263
# -------------
# Reward (Until timestep 2700/5000 of run 2/4):
# -------------
# reward:  0.8099825934168202
# -------------
# Reward (Until timestep 3000/5000 of run 2/4):
# -------------
# reward:  0.9056775671067008
# -------------
# Reward (Until timestep 3300/5000 of run 2/4):
# -------------
# reward:  0.7359814409232558
# -------------
# Reward (Until timestep 3600/5000 of run 2/4):
# -------------
# reward:  0.8161694246438613
# -------------
# Reward (Until timestep 3900/5000 of run 2/4):
# -------------
# reward:  0.825106701871789
# -------------
# Reward (Until timestep 4200/5000 of run 2/4):
# -------------
# reward:  0.7478530613295401
# -------------
# Reward (Until timestep 4500/5000 of run 2/4):
# -------------
# reward:  0.7726035264747212
# -------------
# Reward (Until timestep 4800/5000 of run 2/4):
# -------------
# Total Handovers  over all timesteps: Episode 2= 2815 HOs, reward= 0.8443657717924391
# reward:  0.7907606041483646
# -------------
# Reward (Until timestep 0/5000 of run 3/4):
# -------------
# reward:  0.8479482605190722
# -------------
# Reward (Until timestep 300/5000 of run 3/4):
# -------------
# reward:  0.8085865951641351
# -------------
# Reward (Until timestep 600/5000 of run 3/4):
# -------------
# reward:  0.8811874895294081
# -------------
# Reward (Until timestep 900/5000 of run 3/4):
# -------------
# reward:  0.860663431080046
# -------------
# Reward (Until timestep 1200/5000 of run 3/4):
# -------------
# reward:  0.8410806351898268
# -------------
# Reward (Until timestep 1500/5000 of run 3/4):
# -------------
# reward:  0.9072719619383934
# -------------
# Reward (Until timestep 1800/5000 of run 3/4):
# -------------
# reward:  0.8758882306748242
# -------------
# Reward (Until timestep 2100/5000 of run 3/4):
# -------------
# reward:  0.8471676239305136
# -------------
# Reward (Until timestep 2400/5000 of run 3/4):
# -------------
# reward:  0.8666300624446336
# -------------
# Reward (Until timestep 2700/5000 of run 3/4):
# -------------
# reward:  0.9207021023666037
# -------------
# Reward (Until timestep 3000/5000 of run 3/4):
# -------------
# reward:  0.7407433060122176
# -------------
# Reward (Until timestep 3300/5000 of run 3/4):
# -------------
# reward:  0.6456856975194489
# -------------
# Reward (Until timestep 3600/5000 of run 3/4):
# -------------
# reward:  0.8305600600416843
# -------------
# Reward (Until timestep 3900/5000 of run 3/4):
# -------------
# reward:  0.8633229787267946
# -------------
# Reward (Until timestep 4200/5000 of run 3/4):
# -------------
# reward:  0.86555595555294
# -------------
# Reward (Until timestep 4500/5000 of run 3/4):
# -------------
# reward:  0.9120949251680157
# -------------
# Reward (Until timestep 4800/5000 of run 3/4):
# -------------
# Total Handovers  over all timesteps: Episode 3= 5699 HOs, reward= 0.8475256620122877
# -------------
# Runtime Duration:
# -------------
# -------------
# Avg PRB ratio per user:
# -------------
# -------------
# Avg power ratio per user:
# -------------
# -------------
# Avg PRB utilization per RU:
# -------------
# -------------
# Avg power utilization per RU:
# -------------
# -------------
# User assignment penalty (not effective in solution):
# -------------
# -------------
# logarithmic rewards:
# -------------
# -------------
# Mean episodic rewards:
# -------------
# -------------
# Constraint Satisfaction:
# -------------
# -------------
# SSL Metrics:
# -------------
# -------------
# Comparison of Average E2E Delay (SAC):
# -------------
# -------------
# Average Data Rate (SAC):
# -------------
# -------------
# Average of total allocated power to each user (SAC):
# -------------
# -------------
# Sum of handovers :
# -------------
# -------------
# No. of satisfied delay and rate constraints (Max= 2*U):
# -------------
# Total time for 5000 timesteps (14 users) in 4 Episdoes (aka iterations or epochs): 54.0 minutes 25.59559917449951 seconds

# %%
np.mean(np.average(mat_ssl_rate[:,:-2000], axis=0), axis=0)

# %%
# config.yaml
USER_NO: 14 #10 #20 # 4
BW: 180000  # %  180 kHz  (to be updated after consulting with Faouzi)
PRB_NO: 150 #  (to be updated after consulting with Faouzi)
SIGMA_NOISE: 10**(-17.4) #3.981e-18 # # = -174 dBm <tnsm23nouruzi> #
ETA_AREA: 3 # for rural areas according to TS 38.215 (Used in the Rayleigh/Distance formula for calculating data rate (Shannon)); equal to 3 for rural; 4 for urban areas # check also 38.913 for mobility scenarios and classes
X_LIM: 1000
Y_LIM: 1000
#CU_NO: 1 # only 1 CU is envisioned. It is co-located with the Near-RT RIC
DU_NO: 2 # all connected to the CU
RU_PER_DU_NO: 2 # Each DU has 4 RUs; Total number of RUs = 4*2 = 8
#BS_NO: 20 # should be equal to RU_PER_DU_NO*DU_NO # static for now; Location.bs_location() --- now it is bound to 4 BSs. Can be changed later
FH_BW_CAPACITY: 5000 # 100 Mbps in twc23kavehmadani# Mbps (5 Gbps) (link between RU and its DU) #
E2_BW_CAPACITY: 100000 # 5 Gbps in twc23kavehmadani #Mbps (100 Gbps) (link between DU and Near-RT RIC (equal to F1, which is between DU and CU))
#VM_NO: 9 # 6
#VNF_NO: 5 # 5
#NODE_NO: 12
SLICE_NO: 3 #5 # number of slice types ; will be indexed from 0 to (SLICE_NO - 1)
MAX_POWER: 40 # in watts ; equals to 46 dBm <tvt23choi> # 12 # (to be updated after consulting with Faouzi) # 46 dBm in tvt23choi = 40 watts (Much higher than normal papers)
OMEGA_1: 0.5 # to use in SSL weighting (for data rate term)
VELOCITY: 10 # 10 #0 #-1 means random #35 # m/s [5,20,35,50] #             = self.V ##################################################
CONST_D_MAX: -1 # -1  #-1 # -1 # 20 #-1 # ms
CONST_R_MIN: -1 # -1  #-1 # -1 # 5 #-1 # Mbps  
#ISOLATION_ORDER: -1
PACKET_SIZE: -1  #-1 #-1 # -1 # 0.012 # based on 1500 bytes for eMBB # in mbits # -1 # twc23kavehmadani: 1 KB for URLLC and 125 KB for eMBB
#PACKET_NO: 830  # 500 # -1 # packet generation rate per second # 0.012*500 = 6 Mbps # 0.012*830 = 9.96 Mbps
RAYLEIGH_SCALE: 1 # sigma in Rayleigh formula
#Episodes (T) and Number of monte-carlo runs:#
E: 4 #1000# episodes/epochs for learning (the loop before T loop (replaces MC loop))
T: 5000 #100# 14000 # 1000  # Number of timeslots
#MC: 3  # Number of Monte-carlo runs
#Hyperparameters for the DRL algorithm
ALPHA_ACT: 0.000002 #01 # 0.00001 # 0.00001 #0.000001 # actor's learning rate
BETA_ACT: 0.00001 # 5 # 0.00005 # 0.00005 # 0.00005 # 0.000005 # Critic's learning rate
VAR: 1
DECAY_VAR: 0.999 #95 #95 # .995 # can determine the ratio of exploration to exploitation
PSI: 0.5 # for putting two last actions in states
XI: 3 # shaping parameter for SSL^B_u and SSL^D_u
IOTA: 0.1 # regularization parameter that controls the penalty for low satisfaction levels
