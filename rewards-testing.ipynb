# %%
# %run "main_constraint-based.py"
# Out:
# /share/home2/ebrahimis/project1_3_8/venv/lib/python3.8/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:397: RuntimeWarning: divide by zero encountered in log10
#   self.signal_strength_dB[u] = 10 * np.log10(self.signal_strength)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:401: RuntimeWarning: divide by zero encountered in log10
#   self.SINR_dB[u] = 10 * np.log10(self.SINR)
# /share/home2/ebrahimis/project1_3_8/oran/oran_enabled_mobility_aware_slicing/radio_calc.py:395: RuntimeWarning: divide by zero encountered in log10
#   self.interference_dB[u] = 10 * np.log10(I_inter)
# reward:  0.2695971242191944
# reward:  0.14382992781008663
# reward:  -0.17207926385517136
# Total Handovers  over all timesteps: Episode 0= 0 HOs
# Total Handovers  over all timesteps: Episode 100= 0 HOs
# reward:  -0.06227670067143698
# reward:  0.04694577367119357
# reward:  -0.007185224856040118
# Total Handovers  over all timesteps: Episode 200= 0 HOs
# Total Handovers  over all timesteps: Episode 300= 0 HOs
# reward:  0.1469332229017863
# reward:  0.20139316670340363
# reward:  0.40198172333331206
# Total Handovers  over all timesteps: Episode 400= 0 HOs
# Total Handovers  over all timesteps: Episode 500= 0 HOs
# reward:  0.2190422586296163
# reward:  0.3764325592537405
# reward:  0.40738861700295514
# Total Handovers  over all timesteps: Episode 600= 0 HOs
# Total Handovers  over all timesteps: Episode 700= 0 HOs
# reward:  0.25799921058904873
# reward:  0.16755358019181033
# reward:  0.1809577383350205
# Total Handovers  over all timesteps: Episode 800= 0 HOs
# Total Handovers  over all timesteps: Episode 900= 0 HOs
# reward:  0.25838491803663544
# reward:  0.2973034740211591
# reward:  0.15815476708719578
# Total Handovers  over all timesteps: Episode 1000= 0 HOs
# Total Handovers  over all timesteps: Episode 1100= 0 HOs
# reward:  0.3896234381291787
# reward:  0.06659230555272544
# reward:  0.16709817307986113
# Total Handovers  over all timesteps: Episode 1200= 0 HOs
# Total Handovers  over all timesteps: Episode 1300= 0 HOs
# reward:  0.20482575230437322
# reward:  0.25819576370904523
# reward:  0.3175123047133694
# Total Handovers  over all timesteps: Episode 1400= 0 HOs
# Total Handovers  over all timesteps: Episode 1500= 0 HOs
# reward:  0.37147673325187436
# reward:  0.09647933789476637
# reward:  -0.03894867596958773
# Total Handovers  over all timesteps: Episode 1600= 0 HOs
# Total Handovers  over all timesteps: Episode 1700= 0 HOs
# reward:  0.03776820639370371
# reward:  -0.02097280842902416
# reward:  0.07886546485154633
# Total Handovers  over all timesteps: Episode 1800= 0 HOs
# Total Handovers  over all timesteps: Episode 1900= 0 HOs
# reward:  -0.007484956531933595
# reward:  0.12166362352081339
# reward:  0.16372271215447903
# Total Handovers  over all timesteps: Episode 2000= 0 HOs
# Total Handovers  over all timesteps: Episode 2100= 0 HOs
# reward:  0.3015132157748166
# reward:  0.3012212027388862
# reward:  0.311581468784191
# Total Handovers  over all timesteps: Episode 2200= 0 HOs
# Total Handovers  over all timesteps: Episode 2300= 0 HOs
# reward:  0.2954415553381175
# reward:  0.14448961886579992
# reward:  -0.0033904347639248655
# Total Handovers  over all timesteps: Episode 2400= 0 HOs
# Total Handovers  over all timesteps: Episode 2500= 0 HOs
# reward:  0.09726333401249254
# reward:  0.6283710452417036
# reward:  0.11439218865674317
# Total Handovers  over all timesteps: Episode 2600= 0 HOs
# Total Handovers  over all timesteps: Episode 2700= 0 HOs
# reward:  0.3108634201006701
# reward:  -0.005138785885194008
# reward:  0.22928252274380762
# Total Handovers  over all timesteps: Episode 2800= 0 HOs
# Total Handovers  over all timesteps: Episode 2900= 0 HOs
# reward:  0.066471129869495
# reward:  -0.039332052318282185
# reward:  0.1915309290152366
# Total Handovers  over all timesteps: Episode 3000= 0 HOs
# Total Handovers  over all timesteps: Episode 3100= 0 HOs
# reward:  0.21971850188510494
# reward:  0.271673361223851
# reward:  0.2576491371776091
# Total Handovers  over all timesteps: Episode 3200= 0 HOs
# Total Handovers  over all timesteps: Episode 3300= 0 HOs
# reward:  0.3883817882557947
# reward:  -0.0050661157448742555
# reward:  0.23796718632207042
# Total Handovers  over all timesteps: Episode 3400= 0 HOs
# Total Handovers  over all timesteps: Episode 3500= 0 HOs
# reward:  0.15204948333040857
# reward:  -0.20554489054018332
# reward:  0.206519893828491
# Total Handovers  over all timesteps: Episode 3600= 0 HOs
# Total Handovers  over all timesteps: Episode 3700= 0 HOs
# reward:  0.024827166566573133
# reward:  0.04125064742606532
# reward:  0.32119361003086355
# Total Handovers  over all timesteps: Episode 3800= 0 HOs
# Total Handovers  over all timesteps: Episode 3900= 0 HOs
# reward:  0.16668976365559296
# reward:  0.4331850496296934
# reward:  0.2655054137712528
# Total Handovers  over all timesteps: Episode 4000= 0 HOs
# Total Handovers  over all timesteps: Episode 4100= 0 HOs
# reward:  0.10407501953622633
# reward:  -0.09090052513185831
# reward:  0.10554689652589444
# Total Handovers  over all timesteps: Episode 4200= 0 HOs
# Total Handovers  over all timesteps: Episode 4300= 0 HOs
# reward:  -0.01157917119456775
# reward:  0.2564138197574954
# reward:  0.24078649740711372
# Total Handovers  over all timesteps: Episode 4400= 0 HOs
# Total Handovers  over all timesteps: Episode 4500= 0 HOs

# %%
# config.yaml
USER_NO: 10 #10 #20 # 4
BW: 180000  # %  180 kHz  (to be updated after consulting with Faouzi)
PRB_NO: 200 #  (to be updated after consulting with Faouzi)
SIGMA_NOISE: 10**(-17.4) #3.981e-18 # # = -174 dBm <tnsm23nouruzi> #
ETA_AREA: 3 # for rural areas according to TS 38.215 (Used in the Rayleigh/Distance formula for calculating data rate (Shannon)); equal to 3 for rural; 4 for urban areas # check also 38.913 for mobility scenarios and classes
X_LIM: 1000
Y_LIM: 1000
#CU_NO: 1 # only 1 CU is envisioned. It is co-located with the Near-RT RIC
DU_NO: 1 # all connected to the CU
RU_PER_DU_NO: 4 # Each DU has 4 RUs; Total number of RUs = 4*2 = 8
#BS_NO: 20 # should be equal to RU_PER_DU_NO*DU_NO # static for now; Location.bs_location() --- now it is bound to 4 BSs. Can be changed later
FH_BW_CAPACITY: 5000 # 100 Mbps in twc23kavehmadani# Mbps (5 Gbps) (link between RU and its DU) #
E2_BW_CAPACITY: 100000 # 5 Gbps in twc23kavehmadani #Mbps (100 Gbps) (link between DU and Near-RT RIC (equal to F1, which is between DU and CU))
#VM_NO: 9 # 6
#VNF_NO: 5 # 5
#NODE_NO: 12
SLICE_NO: 1 #5 # number of slice types ; will be indexed from 0 to (SLICE_NO - 1)
MAX_POWER: 40 # in watts ; equals to 46 dBm <tvt23choi> # 12 # (to be updated after consulting with Faouzi) # 46 dBm in tvt23choi = 40 watts (Much higher than normal papers)
OMEGA_1: 0.5 # to use in SSL weighting (for data rate term)
VELOCITY: 0 #0 #-1 means random #35 # m/s [5,20,35,50] #             = self.V ##################################################
CONST_D_MAX: 20 #-1 # ms
CONST_R_MIN: 10 #-1 # Mbps  
#ISOLATION_ORDER: -1
PACKET_SIZE: 0.012 # based on 1500 bytes for eMBB # in mbits # -1 # twc23kavehmadani: 1 KB for URLLC and 125 KB for eMBB
#PACKET_NO: 830  # 500 # -1 # packet generation rate per second # 0.012*500 = 6 Mbps # 0.012*830 = 9.96 Mbps
RAYLEIGH_SCALE: 1 # sigma in Rayleigh formula
#Episodes (T) and Number of monte-carlo runs:#
E: 5000 #1000# episodes/epochs for learning (the loop before T loop (replaces MC loop))
T: 100 #100# 14000 # 1000  # Number of timeslots
#MC: 3  # Number of Monte-carlo runs
#Hyperparameters for the DRL algorithm
ALPHA_ACT: 0.00001 # 0.00001 # 0.00001 #0.000001 # actor's learning rate
BETA_ACT: 0.00005 # 0.00005 # 0.00005 # 0.000005 # Critic's learning rate
VAR: 1
DECAY_VAR: 0.9994 #95 #95 # .995 # can determine the ratio of exploration to exploitation
