# %%
# %run "main.py"
# Out:
# 0
# /home/sina/.local/lib/python3.8/site-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /home/sina/Dropbox/Sina/O-RAN-enabled Slicing/oran_enabled_mobility_aware_slicing/radio_calc.py:272: RuntimeWarning: divide by zero encountered in log10
#   self.signal_strength_dB[u] = 10 * np.log10(self.signal_strength)
# /home/sina/Dropbox/Sina/O-RAN-enabled Slicing/oran_enabled_mobility_aware_slicing/radio_calc.py:276: RuntimeWarning: divide by zero encountered in log10
#   self.SINR_dB[u] = 10 * np.log10(self.SINR)
# /home/sina/Dropbox/Sina/O-RAN-enabled Slicing/oran_enabled_mobility_aware_slicing/radio_calc.py:270: RuntimeWarning: divide by zero encountered in log10
#   self.interference_dB[u] = 10 * np.log10(I_inter)
# Reward: -3.0838597464127844 in episode 0 MC 0
# -------------
# Reward (Until episode 0/4000 of run 0/1):
# -------------
# ...
